# %% [markdown]
# # Exploration of Nutrition and Costs

# %% [markdown]
# data sources:
#
# - https://fdc.nal.usda.gov/download-datasets.html
# - https://www.ers.usda.gov/data-products/fruit-and-vegetable-prices.aspx
# - https://www.kaggle.com/datasets/trolukovich/nutritional-values-for-common-foods-and-products
# - https://www.fda.gov/food/nutrition-facts-label/daily-value-nutrition-and-supplement-facts-labels
#
# -https://marketnews.usda.gov/mnp/FVDataDownload
#
# explored, but discarded:
# - https://www.kaggle.com/datasets/thedevastator/the-nutritional-content-of-food-a-comprehensive
# - https://www.kaggle.com/datasets/thunderz/food-data
#
#
# inspiration sources:
#
# - https://nutritionj.biomedcentral.com/articles/10.1186/s12937-019-0496-5
# - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2954450/
# - https://www.healthline.com/nutrition/29-cheap-healthy-foods
# - https://nutritionfacts.org/blog/best-nutrition-bang-for-your-buck/

# %% [markdown]
# ## Idea/Work Backlog
#
# - before fuzzy matching, create subsets based on matching storage_state and Form (i.e. "Canned" and "Canned", 'Dried'=='Dried')
# - least/most costly calories per gram (`dollars per calorie per gram`)
#     - silimar for other nutrients

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Nutrition and Assess

# %%
# data source:
# https://www.kaggle.com/datasets/trolukovich/nutritional-values-for-common-foods-and-products

nutrition = pd.read_csv('data/nutrition.csv', index_col='Unnamed: 0')

# %%
nutrition.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8789 entries, 0 to 8788
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   object
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   object
#  4   saturated_fat                7199 non-null   object
#  5   cholesterol                  8789 non-null   object
#  6   sodium                       8789 non-null   object
#  7   choline                      8789 non-null   object
#  8   folate                       8789 non-null   object
#  9   folic_acid                   8789 non-null   object
#  10  niacin                       8789 non-null   object
#  11  pantothenic_acid             8789 non-null   object
#  12  riboflavin                   8789 non-null   object
#  13  thiamin                      8789 non-null   object
#  14  vitamin_a                    8789 non-null   object
#  15  vitamin_a_rae                8789 non-null   object
#  16  carotene_alpha               8789 non-null   object
#  17  carotene_beta                8789 non-null   object
#  18  cryptoxanthin_beta           8789 non-null   object
#  19  lutein_zeaxanthin            8789 non-null   object
#  20  lucopene                     8789 non-null   int64
#  21  vitamin_b12                  8789 non-null   object
#  22  vitamin_b6                   8789 non-null   object
#  23  vitamin_c                    8789 non-null   object
#  24  vitamin_d                    8789 non-null   object
#  25  vitamin_e                    8789 non-null   object
#  26  tocopherol_alpha             8789 non-null   object
#  27  vitamin_k                    8789 non-null   object
#  28  calcium                      8789 non-null   object
#  29  copper                       8789 non-null   object
#  30  irom                         8789 non-null   object
#  31  magnesium                    8789 non-null   object
#  32  manganese                    8789 non-null   object
#  33  phosphorous                  8789 non-null   object
#  34  potassium                    8789 non-null   object
#  35  selenium                     8789 non-null   object
#  36  zink                         8789 non-null   object
#  37  protein                      8789 non-null   object
#  38  alanine                      8789 non-null   object
#  39  arginine                     8789 non-null   object
#  40  aspartic_acid                8789 non-null   object
#  41  cystine                      8789 non-null   object
#  42  glutamic_acid                8789 non-null   object
#  43  glycine                      8789 non-null   object
#  44  histidine                    8789 non-null   object
#  45  hydroxyproline               8789 non-null   object
#  46  isoleucine                   8789 non-null   object
#  47  leucine                      8789 non-null   object
#  48  lysine                       8789 non-null   object
#  49  methionine                   8789 non-null   object
#  50  phenylalanine                8789 non-null   object
#  51  proline                      8789 non-null   object
#  52  serine                       8789 non-null   object
#  53  threonine                    8789 non-null   object
#  54  tryptophan                   8789 non-null   object
#  55  tyrosine                     8789 non-null   object
#  56  valine                       8789 non-null   object
#  57  carbohydrate                 8789 non-null   object
#  58  fiber                        8789 non-null   object
#  59  sugars                       8789 non-null   object
#  60  fructose                     8789 non-null   object
#  61  galactose                    8789 non-null   object
#  62  glucose                      8789 non-null   object
#  63  lactose                      8789 non-null   object
#  64  maltose                      8789 non-null   object
#  65  sucrose                      8789 non-null   object
#  66  fat                          8789 non-null   object
#  67  saturated_fatty_acids        8789 non-null   object
#  68  monounsaturated_fatty_acids  8789 non-null   object
#  69  polyunsaturated_fatty_acids  8789 non-null   object
#  70  fatty_acids_total_trans      8789 non-null   object
#  71  alcohol                      8789 non-null   object
#  72  ash                          8789 non-null   object
#  73  caffeine                     8789 non-null   object
#  74  theobromine                  8789 non-null   object
#  75  water                        8789 non-null   object
# dtypes: int64(2), object(74)
# memory usage: 39.2 MB

# %%
nutrition.head()
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g       381      0.1g           NaN           0
# 1     Nuts, pecans        100 g       691       72g          6.2g           0
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 76 columns]

# %%
nutrition[nutrition.name=='Wheat flour, whole-grain'].T
# Out:
#                                        683
# name              Wheat flour, whole-grain
# serving_size                         100 g
# calories                               340
# total_fat                             2.5g
# saturated_fat                         0.4g
# ...                                    ...
# name_split     [Wheat, flour, whole-grain]
# food_types
# storage_state
# grade
# Salt
#
# [81 rows x 1 columns]

# %%
# will use this food dataset since all are 100g serving sizes
# but will need to parse the nutrients from string to numbers and units of measure

# %% [markdown]
# # Categorize based on most frequent words

# %%
# split the name into lists in orders to find the most frequently used words

nutrition['name_split'] = nutrition['name'].apply(lambda x: x.replace(",", "").split())

words = pd.Series([word for EachElement in nutrition['name_split'] for word in EachElement])
words.value_counts()
# Out:
# and          2092
# fat          1994
# cooked       1785
# lean         1508
# separable    1457
#              ...
# VITAMAN         1
# FRUITY          1
# beaked          1
# Hazelnuts       1
# degree          1
# Length: 4514, dtype: int64

# %%
words.value_counts().quantile(q=[0,0.25, 0.50, 0.75, 0.99, 0.999, 0.9999, 1])
# Out:
# 0.0000       1.0000
# 0.2500       1.0000
# 0.5000       2.0000
# 0.7500       7.0000
# 0.9900     242.4800
# 0.9990    1422.6290
# 0.9999    2047.7726
# 1.0000    2092.0000
# dtype: float64

# %%
# top 83 words (of distinct 4514!) is top 50 percent of word counts

(words.value_counts().cumsum()/words.value_counts().sum()).iloc[83]
# Out:
# 0.49999273414226547

# %%
# look up each top word, then look up `name` with that word, analyze, identify groupings


theWord = words.value_counts().index[130]
theWord

# words of interest that can lead to categorizing:

# FOODS
# Babyfood: 'Babyfood'
# Beef: 'Beef'
# Chicken: 'Chicken'
# Pork: 'Pork'
# Lamb: 'Lamb'
# Fish: 'Fish'
# Cheese: 'Cheese'
# Crackers: 'Crackers'
# Soup: 'Soup'
# Cereals: 'Cereals'

# STORAGE STATE
# Fresh: ['fresh', 'raw']
# Frozen: ['frozen', 'raw or frozen']
# Canned: 'canned'
# Dried: 'dry'

# PREPARED
# cooked: 'cooked'
# roasted: 'roasted'
# boiled: 'boiled'
# drained: 'drained'    ## typically with 'boiled'
# solids: ['drained solids', 'solids and liquids']
# prepared: 'prepared'
# uprepared: 'unprepared'
# salt: [without salt, with salt, no salt added]  ## sodium?

# ATTRIBUTES
# boneless: 'boneless'
# fat: ['low fat', 'fat free', 'reducted fat', ...]
# skin: ['skin', 'with skin, without skin', 'meat and skin', 'cooked without skin']

# GRADE
# all: ['all varieties', 'all types', 'all grades']
# choice: 'choice' #like preferred or premium?
# select: 'select' # similar to choice
# imported: imported
# ready-to-eat:ready-to-eat

##################
# explore later
# lean: 'separable lean only', X% fat Y% lean 
# meat:
# water:
# Out:
# 'sodium'

# %%
# lookup records where `name` contains the word

nutrition[nutrition['name_split'].apply(lambda x: theWord in x)].name.iloc[:50]
# Out:
# 282                                    Catsup, low sodium
# 734                         Beef, reduced sodium, bologna
# 739                         Peanut butter, reduced sodium
# 797                          Crackers, low sodium, cheese
# 813                          Cheese, low sodium, parmesan
# 1060                            Cheese, low sodium, swiss
# 1070                            Bacon, low sodium, turkey
# 1242                              Milk, fluid, low sodium
# 1261                              Frankfurter, low sodium
# 1557                    Crackers, low sodium, toast thins
# 1789                      Salami, less sodium, beef, pork
# 1992                       Cheese, low sodium, mozzarella
# 2122              Soup, lower sodium, beef broth, SWANSON
# 2123              Pickles, reduced sodium, dill, cucumber
# 2173              Soup, canned, low sodium, chicken broth
# 2255               Tomato and vegetable juice, low sodium
# 2283               Popcorn, low fat and sodium, microwave
# 2494                 Pork sausage, cooked, reduced sodium
# 2497                 Soup, with water, low sodium, tomato
# 2557                 CAMPBELL'S, low sodium, Tomato juice
# 2616                  Ham, low sodium, extra lean, smoked
# 2669                  Pickles, low sodium, sour, cucumber
# 2714                  Snacks, very low sodium, corn cakes
# 2752         Vegetable juice cocktail, canned, low sodium
# 2825         Gravy, prepared, low sodium, meat or poultry
# 2993          Mayonnaise, low calorie or diet, low sodium
# 3535     Soup, chunk style, low sodium, beef and mushroom
# 3613      Sauce, reduced sodium, ready-to-serve, teriyaki
# 3615      Sausage, reduced sodium, and beef, turkey, pork
# 3710      Soup, reduced sodium, condensed, canned, tomato
# 3764       Beans, low sodium, canned, mature seeds, black
# 3769       Soup, condensed, low sodium, canned, vegetable
# 4156    Soy sauce made from soy and wheat (shoyu), low...
# 4298    Cheese, no sodium added, 1% milkfat, lowfat, c...
# 4481    Soup, dry, low sodium, bouillon cubes and gran...
# 4533    Pork, cooked, lean and fat, low sodium, ham, c...
# 4601    Refried beans, reduced sodium, traditional, ca...
# 4732    Bacon, unprepared, reduced/low sodium, pre-sliced
# 4919    Soup, reduced sodium, condensed, canned, cream...
# 5021    Soup, ready to serve, less/reduced sodium, chi...
# 5024    Sausage,  lower sodium, Italian style, chicken...
# 5032    Bread, no salt, low sodium, commercially prepa...
# 5068    Soup, ready-to-serve, reduced sodium, canned, ...
# 5145    Soup, prepared with equal volume water, low so...
# 5204    Beans, low sodium, canned, mature seeds, great...
# 5346    Jellies, any flavors, no sugar (with sodium sa...
# 5409    Soup, ready to serve, less/reduced sodium, bee...
# 5688    Soup, ready-to-serve, canned, reduced sodium, ...
# 5839    Cheese, low sodium, cheddar or American, paste...
# 5914    Sauce, low sodium, ready-to-serve, spaghetti/m...
# Name: name, dtype: object

# %%
# value count of prhases found by regex

(nutrition[nutrition['name_split']
           .apply(lambda x: 'sodium' in x)]
           .name
           .str.extract(r",([^,]*sodium[^,\n]*)[,\n]")
           .value_counts()
)
# Out:
#  low sodium                                        31
#  reduced sodium                                    20
#  with sodium saccharin                              2
#  less/reduced sodium                                2
#  sodium                                             2
#   lower sodium                                      1
#  reduced/low sodium                                 1
#  without added sodium                               1
#  with lauric acid oil and sodium caseinate          1
#  with added potassium and sodium                    1
#  very low sodium                                    1
#  sweetened with sodium saccharin                    1
#  sodium aluminum sulfate                            1
#  no sodium added                                    1
#  25% less sodium                                    1
#  no added sodium                                    1
#  lower sodium                                       1
#  low sodium no salt                                 1
#  low sodium (includes bread and butter pickles)     1
#  low fat and sodium                                 1
#  less sodium                                        1
#  50% less sodium                                    1
#  without added sodium or vitamin A                  1
# dtype: int64

# %%
(nutrition[nutrition['name_split']
           .apply(lambda x: 'salt' in x)]
           .name
           .str.extract(r",([^,]*salt[^,\n]*)[,\n]")
           .value_counts()
)
# Out:
#  without salt                              245
#  with salt                                 239
#  no salt added                              28
#  with salt added                            25
#  without salt added                         17
#  salt added in processing                   12
#  salt not added in processing                5
#  without added salt                          5
#  with added salt                             4
#  low salt                                    3
#  no salt                                     3
#  salt added                                  3
#  salt                                        2
#  boiled with salt                            1
#  without salt (includes USDA commodity)      1
#  with salt added (decorticated)              1
#  salt pork                                   1
#  with no added salt                          1
#  sodium-citrate and salt                     1
#  skin with salt                              1
#  cooked without salt                         1
#  low sodium no salt                          1
#  low salt (includes oyster                   1
#  drained without salt                        1
#  without salt added (decorticated)           1
# dtype: int64

# %% [markdown]
# ***
# Based on the groupings study and the development of some dictionaries, functions are also built to execute the categorization of these food items.
# ***

# %%
import re

# %%
def categorize(TheSeries: pd.Series, pattern: list, category: str, regex=False):
    if type(pattern) == list:
        for eachItem in pattern:
            if regex:
                pat = fr',([^,]*{eachItem}[^,\n]*)[,\n]'
                return nutrition.name.apply(lambda x: category if re.search(pat,x) else '')
            else:
                return TheSeries.apply(lambda x: category if eachItem in x else '')
    elif type(pattern) == str:
        if regex:
            pat = fr',([^,]*{pattern}[^,\n]*)[,\n]'
            return nutrition.name.apply(lambda x: category if re.search(pat,x) else '')
        else:
            return TheSeries.apply(lambda x: category if pattern in x else '')
    else:
        print("'pattern' parameter dtype is expected to be either str or list")

# %%
def bulk_categorize(theSeries: pd.Series, theDict: dict, column_name, regex=False):
    temp_df = pd.DataFrame()
    for key in theDict:
        tempSeries = categorize(theSeries, theDict[key], key, regex)
        temp_df[key] = tempSeries
    temp_df[column_name] = temp_df.apply(lambda row: ''.join(str(val) for val in row), axis=1)
    temp_df = temp_df[[column_name]]
    return temp_df

# %%
food_types_dict = {
    'Babyfood': 'Babyfood',
    'Beef': 'Beef',
    'Chicken': 'Chicken',
    'Pork': 'Pork',
    'Lamb': 'Lamb',
    'Fish': 'Fish',
    'Cheese': 'Cheese',
    'Crackers': 'Crackers',
    'Soup': 'Soup',
    'Cereals': 'Cereals'
}

storage_state_dict = {
    'Fresh': ['fresh', 'raw'],
    'Frozen': ['frozen', 'raw or frozen'],
    'Canned': 'canned',
    'Dried': 'dry'
}

grade_dict = {
    'all': ['all varieties', 'all types', 'all grades'],
    'choice': 'choice',
    'select': 'select',
    'imported': 'imported',
    'ready_to_eat':'ready-to-eat'
}

salt_dict = {
    'No Salt':['without salt', 'without added sodium', 'no sodium', 
               'no added sodium', 'no salt added', 'without added salt',
               'no salt', 'no added salt', 'without salt added'],
    'Low Salt':['low sodium', 'reduced sodium', 'lower sodium', 'less sodium', 'low salt'],
    'Salt':['with sodium', 'with salt', 'salt added', 'salt']    
}

# %%
s = bulk_categorize(nutrition.name, food_types_dict, 'food_types')
t = bulk_categorize(nutrition.name, storage_state_dict, 'storage_state')
u = bulk_categorize(nutrition.name, grade_dict, 'grade')
v = bulk_categorize(nutrition.name, salt_dict, 'Salt', regex=True)
nutrition = pd.concat([nutrition, s, t, u, v],axis=1)
nutrition
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# 0          381      0.1g           NaN           0   9.00 mg   0.4 mg
# 1          691       72g          6.2g           0   0.00 mg  40.5 mg
# 2           25      0.2g           NaN           0   2.00 mg   6.9 mg
# 3          367      2.4g          0.4g           0  12.00 mg  13.1 mg
# 4          144        2g          1.2g         1mg  46.00 mg   7.7 mg
# ...        ...       ...           ...         ...       ...      ...
# 8784       125      3.5g          1.4g        62mg  54.00 mg  64.5 mg
# 8785       206      8.9g          3.9g       109mg  50.00 mg        0
# 8786       277       23g           12g        78mg  39.00 mg        0
# 8787       121        3g          1.1g        60mg  53.00 mg  64.2 mg
# 8788       121        3g          1.1g        60mg  53.00 mg  64.2 mg
#
#          folate folic_acid  ... alcohol     ash caffeine theobromine    water  \
# 0      0.00 mcg   0.00 mcg  ...   0.0 g  0.09 g  0.00 mg     0.00 mg   8.32 g
# 1     22.00 mcg   0.00 mcg  ...   0.0 g  1.49 g  0.00 mg     0.00 mg   3.52 g
# 2     22.00 mcg   0.00 mcg  ...   0.0 g  0.66 g  0.00 mg     0.00 mg  92.30 g
# 3             0          0  ...       0  2.37 g        0           0   8.82 g
# 4      4.00 mcg   0.00 mcg  ...   0.0 g  0.40 g  0.00 mg     0.00 mg  66.10 g
# ...         ...        ...  ...     ...     ...      ...         ...      ...
# 8784   4.00 mcg   0.00 mcg  ...   0.0 g  1.11 g  0.00 mg     0.00 mg  72.51 g
# 8785   0.00 mcg   0.00 mcg  ...       0  1.60 g        0           0  59.95 g
# 8786   1.00 mcg   0.00 mcg  ...       0  0.92 g        0           0  59.80 g
# 8787   4.00 mcg   0.00 mcg  ...   0.0 g  1.10 g  0.00 mg     0.00 mg  73.43 g
# 8788   4.00 mcg   0.00 mcg  ...   0.0 g  1.10 g  0.00 mg     0.00 mg  73.43 g
#
#                                              name_split food_types  \
# 0                                          [Cornstarch]
# 1                                        [Nuts, pecans]
# 2                                       [Eggplant, raw]
# 3                                      [Teff, uncooked]
# 4                                     [Sherbet, orange]
# ...                                                 ...        ...
# 8784  [Beef, raw, all, grades, trimmed, to, 0", fat,...       Beef
# 8785  [Lamb, cooked, separable, lean, only, composit...       Lamb
# 8786  [Lamb, raw, separable, lean, and, fat, composi...       Lamb
# 8787  [Beef, raw, all, grades, trimmed, to, 0", fat,...       Beef
# 8788  [Beef, raw, all, grades, trimmed, to, 0", fat,...       Beef
#
#      storage_state     grade Salt
# 0
# 1
# 2
# 3
# 4
# ...            ...       ...  ...
# 8784
# 8785        Frozen  imported
# 8786        Frozen  imported
# 8787
# 8788
#
# [8789 rows x 81 columns]

# %% [markdown]
# # EDA on Categories

# %%
# still a lot of records without a `food type`

nutrition.food_types.value_counts()
# Out:
#                      5446
# Beef                  972
# Cereals               352
# Pork                  344
# Chicken               302
# Lamb                  300
# Babyfood              243
# Fish                  239
# Soup                  235
# Cheese                153
# Crackers              120
# ChickenSoup            45
# BeefSoup               16
# CheeseCrackers         12
# CheeseSoup              6
# CheeseCereals           2
# CrackersSoup            1
# ChickenCheeseSoup       1
# Name: food_types, dtype: int64

# %%
nutrition[nutrition.food_types=='CheeseCereals'].name.iloc[0]
# Out:
# "Cereals, dry, Ham 'n' Cheese flavor, Instant Grits, QUAKER"

# %%
nutrition[nutrition.food_types=='CrackersSoup'].name.iloc[0]
# Out:
# 'SUNSHINE, Soup & Oyster Crackers (large), KRISPY'

# %%
nutrition[nutrition.food_types=='ChickenCheeseSoup'].name.iloc[0]
# Out:
# "CAMPBELL'S CHUNKY Soups, Chicken Broccoli Cheese & Potato Soup"

# %%
nutrition.groupby('food_types').agg({'calories':'mean'}).sort_values('calories', ascending=False)
# Out:
#                      calories
# food_types
# CheeseCrackers     487.833333
# Crackers           455.966667
# CrackersSoup       416.000000
# CheeseCereals      357.500000
# Cereals            341.744318
# Cheese             279.490196
#                    232.385053
# Lamb               230.956667
# Pork               214.729651
# Chicken            214.274834
# Beef               210.841564
# Fish               165.426778
# Babyfood           104.962963
# ChickenCheeseSoup   86.000000
# CheeseSoup          77.500000
# Soup                71.970213
# BeefSoup            55.312500
# ChickenSoup         50.844444

# %%
sns.heatmap(nutrition.pivot_table(index='food_types', values='calories', columns='storage_state', aggfunc='mean', margins=True)
            .drop('All')
            .sort_values('All',ascending=False)
            , annot=True, fmt='.0f', cmap='Blues'
           );

# %%
sns.heatmap(nutrition.pivot_table(index='food_types', values='calories', columns='grade', aggfunc='mean', margins=True)
            .drop('All')
            .dropna(how='all',subset=['all','choice','imported','ready_to_eat','select'])
            .sort_values('All',ascending=False)
            , annot=True, fmt='.0f', cmap='Blues'
           );

# %% [markdown]
# # transform Nutrition from wide to long

# %%
# transform from wide to long

food = nutrition.drop('name_split', axis=1).melt(id_vars=['name','food_types','storage_state','grade', 'Salt'])
food['value'] = food['value'].values.astype(str)
food.head()
# Out:
#               name food_types storage_state grade Salt      variable  value
# 0       Cornstarch                                      serving_size  100 g
# 1     Nuts, pecans                                      serving_size  100 g
# 2    Eggplant, raw                                      serving_size  100 g
# 3   Teff, uncooked                                      serving_size  100 g
# 4  Sherbet, orange                                      serving_size  100 g

# %%
pattern = r'(\d+(?:\.\d+)?)\s?(\D+)?'
food[['amount','unit of measure']] = food['value'].str.extract(pattern)
food['amount'] = pd.to_numeric(food['amount'],errors='coerce')

# %%
food[food['name']=='Wheat flour, whole-grain'].head(60)
# Out:
#                             name food_types storage_state grade Salt  \
# 683     Wheat flour, whole-grain
# 9472    Wheat flour, whole-grain
# 18261   Wheat flour, whole-grain
# 27050   Wheat flour, whole-grain
# 35839   Wheat flour, whole-grain
# 44628   Wheat flour, whole-grain
# 53417   Wheat flour, whole-grain
# 62206   Wheat flour, whole-grain
# 70995   Wheat flour, whole-grain
# 79784   Wheat flour, whole-grain
# 88573   Wheat flour, whole-grain
# 97362   Wheat flour, whole-grain
# 106151  Wheat flour, whole-grain
# 114940  Wheat flour, whole-grain
# 123729  Wheat flour, whole-grain
# 132518  Wheat flour, whole-grain
# 141307  Wheat flour, whole-grain
# 150096  Wheat flour, whole-grain
# 158885  Wheat flour, whole-grain
# 167674  Wheat flour, whole-grain
# 176463  Wheat flour, whole-grain
# 185252  Wheat flour, whole-grain
# 194041  Wheat flour, whole-grain
# 202830  Wheat flour, whole-grain
# 211619  Wheat flour, whole-grain
# 220408  Wheat flour, whole-grain
# 229197  Wheat flour, whole-grain
# 237986  Wheat flour, whole-grain
# 246775  Wheat flour, whole-grain
# 255564  Wheat flour, whole-grain
# 264353  Wheat flour, whole-grain
# 273142  Wheat flour, whole-grain
# 281931  Wheat flour, whole-grain
# 290720  Wheat flour, whole-grain
# 299509  Wheat flour, whole-grain
# 308298  Wheat flour, whole-grain
# 317087  Wheat flour, whole-grain
# 325876  Wheat flour, whole-grain
# 334665  Wheat flour, whole-grain
# 343454  Wheat flour, whole-grain
# 352243  Wheat flour, whole-grain
# 361032  Wheat flour, whole-grain
# 369821  Wheat flour, whole-grain
# 378610  Wheat flour, whole-grain
# 387399  Wheat flour, whole-grain
# 396188  Wheat flour, whole-grain
# 404977  Wheat flour, whole-grain
# 413766  Wheat flour, whole-grain
# 422555  Wheat flour, whole-grain
# 431344  Wheat flour, whole-grain
# 440133  Wheat flour, whole-grain
# 448922  Wheat flour, whole-grain
# 457711  Wheat flour, whole-grain
# 466500  Wheat flour, whole-grain
# 475289  Wheat flour, whole-grain
# 484078  Wheat flour, whole-grain
# 492867  Wheat flour, whole-grain
# 501656  Wheat flour, whole-grain
# 510445  Wheat flour, whole-grain
# 519234  Wheat flour, whole-grain
#
#                   variable       value   amount unit of measure
# 683           serving_size       100 g  100.000               g
# 9472              calories         340  340.000             NaN
# 18261            total_fat        2.5g    2.500               g
# 27050        saturated_fat        0.4g    0.400               g
# 35839          cholesterol           0    0.000             NaN
# 44628               sodium     2.00 mg    2.000              mg
# 53417              choline     31.2 mg   31.200              mg
# 62206               folate   44.00 mcg   44.000             mcg
# 70995           folic_acid    0.00 mcg    0.000             mcg
# 79784               niacin    4.957 mg    4.957              mg
# 88573     pantothenic_acid    0.603 mg    0.603              mg
# 97362           riboflavin    0.165 mg    0.165              mg
# 106151             thiamin    0.502 mg    0.502              mg
# 114940           vitamin_a     9.00 IU    9.000              IU
# 123729       vitamin_a_rae    0.00 mcg    0.000             mcg
# 132518      carotene_alpha    0.00 mcg    0.000             mcg
# 141307       carotene_beta    5.00 mcg    5.000             mcg
# 150096  cryptoxanthin_beta    0.00 mcg    0.000             mcg
# 158885   lutein_zeaxanthin  220.00 mcg  220.000             mcg
# 167674            lucopene           0    0.000             NaN
# 176463         vitamin_b12    0.00 mcg    0.000             mcg
# 185252          vitamin_b6    0.407 mg    0.407              mg
# 194041           vitamin_c      0.0 mg    0.000              mg
# 202830           vitamin_d     0.00 IU    0.000              IU
# 211619           vitamin_e     0.71 mg    0.710              mg
# 220408    tocopherol_alpha     0.71 mg    0.710              mg
# 229197           vitamin_k     1.9 mcg    1.900             mcg
# 237986             calcium    34.00 mg   34.000              mg
# 246775              copper    0.410 mg    0.410              mg
# 255564                irom     3.60 mg    3.600              mg
# 264353           magnesium   137.00 mg  137.000              mg
# 273142           manganese    4.067 mg    4.067              mg
# 281931         phosphorous   357.00 mg  357.000              mg
# 290720           potassium   363.00 mg  363.000              mg
# 299509            selenium    61.8 mcg   61.800             mcg
# 308298                zink     2.60 mg    2.600              mg
# 317087             protein     13.21 g   13.210               g
# 325876             alanine     0.489 g    0.489               g
# 334665            arginine     0.648 g    0.648               g
# 343454       aspartic_acid     0.722 g    0.722               g
# 352243             cystine     0.275 g    0.275               g
# 361032       glutamic_acid     4.328 g    4.328               g
# 369821             glycine     0.569 g    0.569               g
# 378610           histidine     0.357 g    0.357               g
# 387399      hydroxyproline           0    0.000             NaN
# 396188          isoleucine     0.443 g    0.443               g
# 404977             leucine     0.898 g    0.898               g
# 413766              lysine     0.359 g    0.359               g
# 422555          methionine     0.228 g    0.228               g
# 431344       phenylalanine     0.682 g    0.682               g
# 440133             proline     2.075 g    2.075               g
# 448922              serine     0.620 g    0.620               g
# 457711           threonine     0.367 g    0.367               g
# 466500          tryptophan     0.174 g    0.174               g
# 475289            tyrosine     0.275 g    0.275               g
# 484078              valine     0.564 g    0.564               g
# 492867        carbohydrate     71.97 g   71.970               g
# 501656               fiber      10.7 g   10.700               g
# 510445              sugars      0.41 g    0.410               g
# 519234            fructose      0.05 g    0.050               g

# %%
food = food.drop(labels=['value'], axis=1)
food
# Out:
#                                                      name food_types  \
# 0                                              Cornstarch
# 1                                            Nuts, pecans
# 2                                           Eggplant, raw
# 3                                          Teff, uncooked
# 4                                         Sherbet, orange
# ...                                                   ...        ...
# 659170  Beef, raw, all grades, trimmed to 0" fat, sepa...       Beef
# 659171  Lamb, cooked, separable lean only, composite o...       Lamb
# 659172  Lamb, raw, separable lean and fat, composite o...       Lamb
# 659173  Beef, raw, all grades, trimmed to 0" fat, sepa...       Beef
# 659174  Beef, raw, all grades, trimmed to 0" fat, sepa...       Beef
#
#        storage_state     grade Salt      variable  amount unit of measure
# 0                                    serving_size  100.00               g
# 1                                    serving_size  100.00               g
# 2                                    serving_size  100.00               g
# 3                                    serving_size  100.00               g
# 4                                    serving_size  100.00               g
# ...              ...       ...  ...           ...     ...             ...
# 659170                                      water   72.51               g
# 659171        Frozen  imported              water   59.95               g
# 659172        Frozen  imported              water   59.80               g
# 659173                                      water   73.43               g
# 659174                                      water   73.43               g
#
# [659175 rows x 8 columns]

# %% [markdown]
# # Load Price Data

# %%
fruit = pd.read_csv('https://www.ers.usda.gov/webdocs/DataFiles/51035/Fruit%20Prices%202020.csv')
veg = pd.read_csv('https://www.ers.usda.gov/webdocs/DataFiles/51035/Vegetable%20Prices%202020.csv')

# %%
fruit = fruit.rename(columns={ fruit.columns[0]: "Item" })
veg = veg.rename(columns={ veg.columns[0]: "Item" })
prices = pd.concat([fruit, veg]).reset_index(drop=True)
prices.tail()
# Out:
#               Item    Form  RetailPrice RetailPriceUnit   Yield  \
# 150       Tomatoes  Canned       1.0175       per pound  1.0000
# 151  Turnip greens   Fresh       2.4176       per pound  0.7500
# 152  Turnip greens  Canned       1.0429       per pound  0.6500
# 153  Turnip greens  Frozen       1.9451       per pound  0.7760
# 154       Zucchini   Fresh       1.5489       per pound  0.7695
#
#      CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# 150             0.5401            pounds              0.5496
# 151             0.3197            pounds              1.0304
# 152             0.3527            pounds              0.5660
# 153             0.3527            pounds              0.8841
# 154             0.3968            pounds              0.7987

# %%
# only juice prices are per pint; everything else is per pound--convertable to grams

prices.groupby(['RetailPriceUnit','Form'])['Item'].count()
# Out:
# RetailPriceUnit  Form
# per pint         Juice     11
# per pound        Canned    36
#                  Dried     17
#                  Fresh     66
#                  Frozen    25
# Name: Item, dtype: int64

# %%
prices = (prices[~(prices['RetailPriceUnit'] == 'per pint')]
          .drop(['RetailPriceUnit', 'Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)
          .copy()
         )

# %%
GRAMS_PER_POUND = 453.5924
prices['PricePer100Grams'] = prices['RetailPrice']/GRAMS_PER_POUND*100
prices.head()
# Out:
#                                  Item    Form  RetailPrice  PricePer100Grams
# 0                              Apples   Fresh       1.5193          0.334948
# 1                  Apples, applesauce  Canned       1.0660          0.235013
# 4                            Apricots   Fresh       2.9665          0.654001
# 5           Apricots, packed in juice  Canned       1.6905          0.372691
# 6  Apricots, packed in syrup or water  Canned       2.0600          0.454152

# %% [markdown]
# # Fuzzy Match Analysis

# %%
# fuzzymatch food.name with prices.Item

from rapidfuzz import fuzz
from rapidfuzz import process
from rapidfuzz import utils
import time

# %%
fuzzyMatchEnabled = True #switch to False if running fuzzymatch is unwanted

# %%
def elapse(start):
    end = time.time() - start
    if end > 60:
        end = round(end/60,1)
        m = "minutes"
    else:
        end = round(end, 1)
        m = "seconds"
    print(f'{end} {m} elapsed')

# %%
def fuzzymatch(series1, series2, threshold=95):
    s = time.time()
    matches = []
    
    for item in series1:
        closest_match, score, ind = process.extractOne(item, series2, processor=utils.default_process)
        if score >= threshold:
            matches.append({series1.name:item,series2.name:closest_match, 'score':score})
    elapse(s)
    return pd.DataFrame(matches)

# %%
matched_df = fuzzymatch(nutrition['name'].drop_duplicates(), prices['Item'].drop_duplicates(), 90)
# Out:
# 5.3 seconds elapsed

# %%
matched_df.head(10)
# Out:
#                      name              Item  score
# 0              Cornstarch              Corn   90.0
# 1        Cauliflower, raw       Cauliflower   95.0
# 2  Grapes, raw, muscadine            Grapes   90.0
# 3  Broccoli, raw, chinese          Broccoli   90.0
# 4  Lentils, raw, sprouted           Lentils   90.0
# 5  Snacks, cakes, popcorn              Corn   90.0
# 6   Brussels sprouts, raw  Brussels sprouts   95.0
# 7   Broccoli raab, cooked          Broccoli   90.0
# 8   Broccoli, raw, leaves          Broccoli   90.0
# 9   Tomatoes, raw, orange          Tomatoes   90.0

# %%
matched_df.groupby(['Item', 'name'])[['score']].count().index.values
# Out:
# array([('Apples', 'Apples, boiled, cooked, without skin, raw'),
#        ('Apples', 'Apples, heated, unsweetened, frozen'),
#        ('Apples', 'Apples, microwave, cooked, without skin, raw'),
#        ('Apples', 'Apples, uncooked, sulfured, dried'),
#        ('Apples', 'Apples, unheated, unsweetened, frozen'),
#        ('Apples', 'Apples, with skin, fuji, raw'),
#        ('Apples', 'Apples, with skin, gala, raw'),
#        ('Apples', 'Apples, with skin, golden delicious, raw'),
#        ('Apples', 'Apples, with skin, granny smith, raw'),
#        ('Apples', 'Apples, with skin, raw'),
#        ('Apples', 'Apples, with skin, red delicious, raw'),
#        ('Apples', 'Apples, without skin, raw'),
#        ('Apples', 'Applesauce, with salt, sweetened, canned'),
#        ('Apples', 'Babyfood, dry, rice and apples'),
#        ('Apples', 'Babyfood, junior, applesauce with banana, fruit'),
#        ('Apples', 'Babyfood, junior, applesauce, fruit'),
#        ('Apples', 'Babyfood, strained, apples and chicken, dinner'),
#        ('Apples', 'Babyfood, strained, apples with ham'),
#        ('Apples', 'Babyfood, strained, applesauce, fruit'),
#        ('Apples', 'Babyfood, toddler, dices, apples'),
#        ('Apples', 'Crabapples, raw'), ('Apples', 'Rose-apples, raw'),
#        ('Apples', 'Sugar-apples, raw, (sweetsop)'),
#        ('Apricots', 'Apricots, drained, heavy syrup, canned'),
#        ('Apricots', 'Apricots, raw'),
#        ('Apricots', 'Apricots, solids and liquids, with skin, juice pack, canned'),
#        ('Apricots', 'Apricots, solids and liquids, with skin, water pack, canned'),
#        ('Apricots', 'Apricots, solids and liquids, without skin, water pack, canned'),
#        ('Apricots', 'Apricots, stewed, sulfured, dehydrated (low-moisture)'),
#        ('Apricots', 'Apricots, sweetened, frozen'),
#        ('Apricots', 'Apricots, uncooked, sulfured, dehydrated (low-moisture)'),
#        ('Apricots', 'Apricots, uncooked, sulfured, dried'),
#        ('Apricots', 'Apricots, with added sugar, stewed, sulfured, dried'),
#        ('Apricots', 'Apricots, without added sugar, stewed, sulfured, dried'),
#        ('Apricots', 'Babyfood, junior, applesauce and apricots, fruit'),
#        ('Apricots', 'Babyfood, strained, applesauce and apricots, fruit'),
#        ('Artichoke', 'Artichokes, raw, (globe or french)'),
#        ('Artichoke', 'Artichokes, unprepared, frozen, (globe or french)'),
#        ('Artichoke', 'Artichokes, with salt, drained, boiled, cooked, (globe or french)'),
#        ('Artichoke', 'Artichokes, without salt, drained, boiled, cooked, (globe or french)'),
#        ('Artichoke', 'Jerusalem-artichokes, raw'),
#        ('Artichoke', 'KASHI Spinach Artichoke Pasta, unprepared, frozen'),
#        ('Asparagus', 'Asparagus, drained solids, canned'),
#        ('Asparagus', 'Asparagus, drained, boiled, cooked'),
#        ('Asparagus', 'Asparagus, raw'),
#        ('Asparagus', 'Asparagus, solids and liquids, no salt added, canned'),
#        ('Asparagus', 'Asparagus, solids and liquids, regular pack, canned'),
#        ('Asparagus', 'Asparagus, unprepared, frozen'),
#        ('Asparagus', 'Asparagus, with salt, drained, boiled, cooked'),
#        ('Asparagus', 'Asparagus, with salt, drained, boiled, cooked, frozen'),
#        ('Asparagus', 'Asparagus, without salt, drained, boiled, cooked, frozen'),
#        ('Asparagus', "CAMPBELL'S Red and White, condensed, Cream of Asparagus Soup"),
#        ('Asparagus', 'KASHI Mushroom & Asparagus Risotto, unprepared, frozen'),
#        ('Asparagus', 'Soup, condensed, canned, cream of asparagus'),
#        ('Asparagus', 'Soup, prepared with equal volume milk, canned, cream of asparagus'),
#        ('Asparagus', 'Soup, prepared with equal volume water, canned, cream of asparagus'),
#        ('Avocados', 'Avocados, California, raw'),
#        ('Avocados', 'Avocados, Florida, raw'),
#        ('Avocados', 'Avocados, all commercial varieties, raw'),
#        ('Bananas', 'Babyfood, dry, with bananas, mixed, cereal'),
#        ('Bananas', 'Babyfood, dry, with bananas, oatmeal, cereal'),
#        ('Bananas', 'Babyfood, dry, with bananas, rice, cereal'),
#        ('Bananas', 'Babyfood, junior, bananas with tapioca, fruit'),
#        ('Bananas', 'Babyfood, strained, bananas and rice, plums'),
#        ('Bananas', 'Babyfood, strained, bananas with tapioca, fruit'),
#        ('Bananas', 'Bananas, or banana powder, dehydrated'),
#        ('Bananas', 'Bananas, raw'),
#        ('Beets', 'Babyfood, strained, beets, vegetables'),
#        ('Beets', 'Beets, drained solids, canned'),
#        ('Beets', 'Beets, drained, boiled, cooked'),
#        ('Beets', 'Beets, raw'),
#        ('Black beans', 'Restaurant, Arroz con frijoles negros (rice and black beans), Latino'),
#        ('Blackberries', 'Blackberries, raw'),
#        ('Blackberries', 'Blackberries, raw (Alaska Native), wild'),
#        ('Blackberries', 'Blackberries, solids and liquids, heavy syrup, canned'),
#        ('Blackberries', 'Blackberries, unsweetened, frozen'),
#        ('Blueberries', 'Blueberries, drained, heavy syrup, canned, wild'),
#        ('Blueberries', 'Blueberries, drained, light syrup, canned'),
#        ('Blueberries', 'Blueberries, frozen (Alaska Native), wild'),
#        ('Blueberries', 'Blueberries, frozen, wild'),
#        ('Blueberries', 'Blueberries, raw'),
#        ('Blueberries', 'Blueberries, raw (Alaska Native), wild'),
#        ('Blueberries', 'Blueberries, solids and liquids, heavy syrup, canned'),
#        ('Blueberries', 'Blueberries, sweetened, dried'),
#        ('Blueberries', 'Blueberries, sweetened, frozen'),
#        ('Blueberries', 'Blueberries, unsweetened, frozen'),
#        ('Broccoli', 'Babyfood, junior, broccoli and chicken, dinner'),
#        ('Broccoli', 'Babyfood, toddlers, mashed cheddar potatoes and broccoli'),
#        ('Broccoli', 'Broccoli raab, cooked'),
#        ('Broccoli', 'Broccoli raab, raw'),
#        ('Broccoli', 'Broccoli, cooked, chinese'),
#        ('Broccoli', 'Broccoli, raw'),
#        ('Broccoli', 'Broccoli, raw, chinese'),
#        ('Broccoli', 'Broccoli, raw, flower clusters'),
#        ('Broccoli', 'Broccoli, raw, leaves'),
#        ('Broccoli', 'Broccoli, raw, stalks'),
#        ('Broccoli', 'Broccoli, unprepared, chopped, frozen'),
#        ('Broccoli', 'Broccoli, with salt, drained, boiled, cooked'),
#        ('Broccoli', 'Broccoli, with salt, drained, boiled, cooked, chopped, frozen'),
#        ('Broccoli', 'Broccoli, with salt, drained, boiled, cooked, spears, frozen'),
#        ('Broccoli', 'Broccoli, without salt, drained, boiled, cooked'),
#        ('Broccoli', 'Broccoli, without salt, drained, boiled, cooked, spears, frozen'),
#        ('Broccoli', "CAMPBELL'S CHUNKY Soups, Chicken Broccoli Cheese & Potato Soup"),
#        ('Broccoli', "CAMPBELL'S Homestyle Potato Broccoli Cheese Soup"),
#        ('Broccoli', "CAMPBELL'S Red and White, condensed, Broccoli Cheese Soup"),
#        ('Broccoli', "CAMPBELL'S Red and White, condensed, Cream of Broccoli Soup"),
#        ('Broccoli', "CAMPBELL'S Soup on the Go, Creamy Broccoli Soup"),
#        ('Broccoli', "CAMPBELL'S, condensed, 98% Fat Free Broccoli Cheese Soup"),
#        ('Broccoli', "CAMPBELL'S, condensed, 98% Fat Free Cream of Broccoli Soup"),
#        ('Broccoli', 'Soup, commercial, condensed, canned, broccoli cheese'),
#        ('Brussels sprouts', 'Brussels sprouts, raw'),
#        ('Brussels sprouts', 'Brussels sprouts, unprepared, frozen'),
#        ('Brussels sprouts', 'Brussels sprouts, with salt, drained, boiled, cooked'),
#        ('Brussels sprouts', 'Brussels sprouts, with salt, drained, boiled, cooked, frozen'),
#        ('Brussels sprouts', 'Brussels sprouts, without salt, drained, boiled, cooked'),
#        ('Brussels sprouts', 'Brussels sprouts, without salt, drained, boiled, cooked, frozen'),
#        ('Butternut squash', 'Babyfood, butternut squash and corn, vegetable'),
#        ('Butternut squash', "CAMPBELL'S Homestyle Butternut Squash Bisque"),
#        ('Cabbage, red', 'Cabbage, raw, red'),
#        ('Cantaloupe', 'Melons, raw, cantaloupe'),
#        ('Carrots', 'Babyfood, junior, carrots, vegetables'),
#        ('Carrots', 'Babyfood, strained, carrots and beef'),
#        ('Carrots', 'Babyfood, strained, carrots, vegetables'),
#        ('Carrots', 'Babyfood, toddler, carrots'),
#        ('Carrots', 'Carrots, drained solids, no salt added, canned'),
#        ('Carrots', 'Carrots, drained solids, regular pack, canned'),
#        ('Carrots', 'Carrots, solids and liquids, no salt added, canned'),
#        ('Carrots', 'Carrots, solids and liquids, regular pack, canned'),
#        ('Carrots', 'Carrots, unprepared, frozen'),
#        ('Carrots', 'Carrots, with salt, drained, boiled, cooked'),
#        ('Carrots', 'Carrots, with salt, drained, boiled, cooked, frozen'),
#        ('Carrots', 'Carrots, without salt, drained, boiled, cooked'),
#        ('Carrots', 'Carrots, without salt, drained, boiled, cooked, frozen'),
#        ('Carrots', 'Peas and carrots, unprepared, frozen'),
#        ('Carrots, baby', 'Carrots, raw, baby'),
#        ('Carrots, raw whole', 'Carrots, raw'),
#        ('Cauliflower', 'Cauliflower, no salt added, cooked, green'),
#        ('Cauliflower', 'Cauliflower, raw'),
#        ('Cauliflower', 'Cauliflower, raw, green'),
#        ('Cauliflower', 'Cauliflower, unprepared, frozen'),
#        ('Cauliflower', 'Cauliflower, with salt, cooked, green'),
#        ('Cauliflower', 'Cauliflower, with salt, drained, boiled, cooked'),
#        ('Cauliflower', 'Cauliflower, with salt, drained, boiled, cooked, frozen'),
#        ('Cauliflower', 'Cauliflower, without salt, drained, boiled, cooked'),
#        ('Cauliflower', 'Cauliflower, without salt, drained, boiled, cooked, frozen'),
#        ('Cauliflower', 'Pickles, sweet, with cauliflower onion mustard, chowchow'),
#        ('Cherries', 'Babyfood, junior, applesauce and cherries, fruit'),
#        ('Cherries', 'Babyfood, strained, applesauce and cherries, fruit'),
#        ('Cherries', 'Cherries, drained, heavy syrup, pitted, canned, sweet'),
#        ('Cherries', 'Cherries, drained, water pack, canned, sour'),
#        ('Cherries', 'Cherries, raw, red, sour'),
#        ('Cherries', 'Cherries, raw, sweet'),
#        ('Cherries', 'Cherries, solids and liquids, juice pack, canned, sweet'),
#        ('Cherries', 'Cherries, solids and liquids, light syrup pack, canned, sweet'),
#        ('Cherries', 'Cherries, solids and liquids, water pack, canned, sweet'),
#        ('Cherries', 'Cherries, sweetened, dried, tart'),
#        ('Cherries', 'Cherries, sweetened, frozen, sweet'),
#        ('Cherries', 'Cherries, unsweetened, frozen, red, sour'),
#        ('Cherries', 'Chokecherries, pitted (Northern Plains Indians), raw'),
#        ('Cherries', 'Chokecherries, pitted (Shoshone Bannock), raw'),
#        ('Cherries', 'Groundcherries, raw, (cape-gooseberries or poha)'),
#        ('Cherries', 'Maraschino cherries, drained, canned'),
#        ('Clementines', 'Clementines, raw'), ('Collard greens', 'Lard'),
#        ('Corn', 'Acorn stew (Apache)'), ('Corn', 'Corn bran, crude'),
#        ('Corn', 'Corn dogs, prepared, frozen'),
#        ('Corn', 'Corn flour, white, whole-grain'),
#        ('Corn', 'Corn flour, yellow, whole-grain'),
#        ('Corn', 'Corn grain, white'), ('Corn', 'Corn grain, yellow'),
#        ('Corn', 'Corn pudding, home prepared'),
#        ('Corn', 'Corn, dried (Navajo)'),
#        ('Corn', 'Corn, raw, white, sweet'),
#        ('Corn', 'Corn, raw, yellow, sweet'),
#        ('Corn', 'Corn, steamed (Navajo), white'),
#        ('Corn', 'Corned beef loaf, jellied'),
#        ('Corn', 'Cornmeal, blue (Navajo)'),
#        ('Corn', 'Cornmeal, white (Navajo)'),
#        ('Corn', 'Cornmeal, white, whole-grain'),
#        ('Corn', 'Cornmeal, yellow (Navajo)'),
#        ('Corn', 'Cornmeal, yellow, whole-grain'),
#        ('Corn', 'Cornsalad, raw'), ('Corn', 'Cornstarch'),
#        ('Corn', "KELLOGG'S, Corn Flakes Crumbs"),
#        ('Corn', 'KFC, Popcorn Chicken'),
#        ('Corn', 'Muffins, toaster-type, corn'),
#        ('Corn', 'Nuts, dried, acorns'),
#        ('Corn', 'Nuts, full fat, acorn flour'),
#        ('Corn', 'Nuts, raw, acorns'),
#        ('Corn', 'Oil, and olive, peanut, corn'),
#        ('Corn', 'Oil, corn and canola'),
#        ('Corn', 'Pasta, dry, corn, gluten-free'),
#        ('Corn', 'Snacks, air-popped, popcorn'),
#        ('Corn', 'Snacks, cakes, popcorn'),
#        ('Corn', 'Snacks, cheese-flavor, popcorn'),
#        ('Corn', 'Snacks, corn cakes'),
#        ('Corn', 'Snacks, plain, CORNNUTS, KRAFT'),
#        ('Corn', 'Squash, raw, acorn, winter'),
#        ('Corn', 'Stew, steamed corn (Navajo)'),
#        ('Corn', 'Succotash, raw, (corn and limas)'),
#        ('Corn', 'Syrups, dark, corn'),
#        ('Corn', 'Syrups, high-fructose, corn'),
#        ('Corn', 'Syrups, light, corn'), ('Corn', 'Tostada shells, corn'),
#        ('Cranberries', "Cereals ready-to-eat, KELLOGG'S RAISIN BRAN with cranberries, KELLOGG"),
#        ('Cranberries', 'Cranberries, raw'),
#        ('Cranberries', 'Cranberries, raw (Alaska Native), bush, wild'),
#        ('Cranberries', 'Cranberries, sweetened, dried'),
#        ('Dates', 'Dates, deglet noor'), ('Dates', 'Dates, medjool'),
#        ('Figs', 'Figs, raw'), ('Figs', 'Figs, stewed, dried'),
#        ('Figs', 'Figs, uncooked, dried'),
#        ('Grapefruit', 'Beverages, canned, pineapple and grapefruit juice drink'),
#        ('Grapefruit', 'Grapefruit juice, OCEAN SPRAY, unsweetened, bottled, white'),
#        ('Grapefruit', 'Grapefruit juice, raw, pink'),
#        ('Grapefruit', 'Grapefruit juice, raw, white'),
#        ('Grapefruit', 'Grapefruit juice, sweetened, canned, white'),
#        ('Grapefruit', 'Grapefruit juice, undiluted, unsweetened, frozen concentrate, white'),
#        ('Grapefruit', 'Grapefruit juice, unsweetened, canned or bottled, white'),
#        ('Grapefruit', 'Grapefruit juice, with added calcium, pink or red'),
#        ('Grapefruit', 'Grapefruit, California and Arizona, pink and red, raw'),
#        ('Grapefruit', 'Grapefruit, California, white, raw'),
#        ('Grapefruit', 'Grapefruit, Florida, pink and red, raw'),
#        ('Grapefruit', 'Grapefruit, Florida, white, raw'),
#        ('Grapefruit', 'Grapefruit, all areas, pink and red and white, raw'),
#        ('Grapefruit', 'Grapefruit, all areas, pink and red, raw'),
#        ('Grapefruit', 'Grapefruit, all areas, white, raw'),
#        ('Grapefruit', 'Grapefruit, solids and liquids, juice pack, canned, sections'),
#        ('Grapefruit', 'Grapefruit, solids and liquids, light syrup pack, canned, sections'),
#        ('Grapefruit', 'Grapefruit, solids and liquids, water pack, canned, sections'),
#        ('Grapefruit', 'Orange-grapefruit juice, unsweetened, canned or bottled'),
#        ('Grapes', 'Grapes, raw, american type (slip skin)'),
#        ('Grapes', 'Grapes, raw, muscadine'), ('Grapes', 'Oil, grapeseed'),
#        ('Green beans', 'Babyfood, green beans and potatoes, vegetable'),
#        ('Green beans', 'Babyfood, junior, green beans, vegetables'),
#        ('Green beans', 'Babyfood, strained, green beans and turkey'),
#        ('Green beans', 'Babyfood, strained, green beans, vegetables'),
#        ('Green beans', 'Babyfood, toddler, dices, green beans'),
#        ('Green beans', 'Vegetables, no salt added, mixed (corn, lima beans, peas, green beans, carrots) canned'),
#        ('Green peppers', 'Corn with red and green peppers, solids and liquids, canned'),
#        ('Green peppers', 'Tomato products, and celery, green peppers, with onions, sauce, canned'),
#        ('Honeydew', 'Honey'), ('Honeydew', 'Melons, raw, honeydew'),
#        ('Kale', 'Kale, raw'), ('Kale', 'Kale, raw, scotch'),
#        ('Kale', 'Kale, unprepared, frozen'),
#        ('Kidney beans', 'Beans, liquid from stewed kidney beans'),
#        ('Kiwi', 'Kiwifruit, raw, ZESPRI SunGold'),
#        ('Kiwi', 'Kiwifruit, raw, green'), ('Lentils', 'Lentils, raw'),
#        ('Lentils', 'Lentils, raw, pink or red'),
#        ('Lentils', 'Lentils, raw, sprouted'),
#        ('Lentils', 'Lentils, with salt, boiled, cooked, mature seeds'),
#        ('Lentils', 'Lentils, with salt, stir-fried, cooked, sprouted'),
#        ('Lentils', 'Lentils, without salt, boiled, cooked, mature seeds'),
#        ('Lentils', 'Lentils, without salt, stir-fried, cooked, sprouted'),
#        ('Lima beans', 'Lima beans, canned, mature seeds, large'),
#        ('Lima beans', 'Lima beans, raw, immature seeds'),
#        ('Lima beans', 'Lima beans, raw, mature seeds, large'),
#        ('Lima beans', 'Lima beans, raw, mature seeds, thin seeded (baby)'),
#        ('Lima beans', 'Lima beans, solids and liquids, no salt added, canned, immature seeds'),
#        ('Lima beans', 'Lima beans, solids and liquids, regular pack, canned, immature seeds'),
#        ('Lima beans', 'Lima beans, unprepared, baby, frozen, immature seeds'),
#        ('Lima beans', 'Lima beans, unprepared, fordhook, frozen, immature seeds'),
#        ('Lima beans', 'Lima beans, with salt, boiled, cooked, mature seeds, large'),
#        ('Lima beans', 'Lima beans, with salt, boiled, cooked, mature seeds, thin seeded (baby)'),
#        ('Lima beans', 'Lima beans, with salt, drained, boiled, cooked, baby, frozen, immature seeds'),
#        ('Lima beans', 'Lima beans, with salt, drained, boiled, cooked, immature seeds'),
#        ('Lima beans', 'Lima beans, without salt, boiled, cooked, mature seeds, large'),
#        ('Lima beans', 'Lima beans, without salt, boiled, cooked, mature seeds, thin seeded (baby)'),
#        ('Lima beans', 'Lima beans, without salt, drained, boiled, cooked, baby, frozen, immature seeds'),
#        ('Lima beans', 'Lima beans, without salt, drained, boiled, cooked, immature seeds'),
#        ('Mustard greens', 'Mustard greens, raw'),
#        ('Mustard greens', 'Mustard greens, unprepared, frozen'),
#        ('Mustard greens', 'Mustard greens, with salt, drained, boiled, cooked'),
#        ('Mustard greens', 'Mustard greens, with salt, drained, boiled, cooked, frozen'),
#        ('Mustard greens', 'Mustard greens, without salt, drained, boiled, cooked'),
#        ('Mustard greens', 'Mustard greens, without salt, drained, boiled, cooked, frozen'),
#        ('Nectarines', 'Nectarines, raw'), ('Okra', 'Okra, raw'),
#        ('Okra', 'Okra, unprepared, frozen'),
#        ('Olives', 'Olives, canned (jumbo-super colossal), ripe'),
#        ('Olives', 'Olives, canned (small-extra large), ripe'),
#        ('Olives', 'Olives, green, canned or bottled, pickled'),
#        ('Onions', "Gravy, brown with onions, CAMPBELL'S"),
#        ('Onions', 'Onions, dehydrated flakes'), ('Onions', 'Onions, raw'),
#        ('Onions', 'Onions, raw, sweet'), ('Onions', 'Onions, raw, welsh'),
#        ('Onions', 'Onions, sauteed, yellow'),
#        ('Onions', 'Onions, solids and liquids, canned'),
#        ('Onions', 'Onions, tops only, young green'),
#        ('Onions', 'Onions, unprepared, chopped, frozen'),
#        ('Onions', 'Onions, unprepared, whole, frozen'),
#        ('Onions', 'Onions, with salt, drained, boiled, cooked'),
#        ('Onions', 'Onions, without salt, drained, boiled, cooked'),
#        ('Onions', 'Peas and onions, solids and liquids, canned'),
#        ('Onions', 'Peas and onions, unprepared, frozen'),
#        ('Onions', 'Tomato products, with onions, sauce, canned'),
#        ('Oranges', 'Oranges, Florida, raw'),
#        ('Oranges', 'Oranges, all commercial varieties, raw'),
#        ('Oranges', 'Oranges, navels, raw'),
#        ('Oranges', 'Oranges, valencias, California, raw'),
#        ('Oranges', 'Oranges, with peel, raw'),
#        ('Oranges', 'Tangerines, juice pack, canned, (mandarin oranges)'),
#        ('Oranges', 'Tangerines, light syrup pack, canned, (mandarin oranges)'),
#        ('Oranges', 'Tangerines, raw, (mandarin oranges)'),
#        ('Papaya', 'Papaya nectar, canned'),
#        ('Papaya', 'Papaya, drained, heavy syrup, canned'),
#        ('Papaya', 'Papayas, raw'),
#        ('Peaches', 'Babyfood, junior, peaches, fruit'),
#        ('Peaches', 'Babyfood, strained, peaches, fruit'),
#        ('Peaches', 'Babyfood, toddler, dices, peaches'),
#        ('Peaches', 'Peaches, drained, heavy syrup, canned'),
#        ('Peaches', 'Peaches, raw, yellow'),
#        ('Peaches', 'Peaches, solids and liquids, extra light syrup, canned'),
#        ('Peaches', 'Peaches, solids and liquids, heavy syrup pack, canned'),
#        ('Peaches', 'Peaches, solids and liquids, juice pack, canned'),
#        ('Peaches', 'Peaches, solids and liquids, light syrup pack, canned'),
#        ('Peaches', 'Peaches, solids and liquids, water pack, canned'),
#        ('Peaches', 'Peaches, stewed, sulfured, dehydrated (low-moisture)'),
#        ('Peaches', 'Peaches, sweetened, sliced, frozen'),
#        ('Peaches', 'Peaches, uncooked, sulfured, dehydrated (low-moisture)'),
#        ('Peaches', 'Peaches, uncooked, sulfured, dried'),
#        ('Peaches', 'Peaches, with added sugar, stewed, sulfured, dried'),
#        ('Peaches', 'Peaches, without added sugar, stewed, sulfured, dried'),
#        ('Peaches', 'USDA Commodity peaches, drained, light syrup, canned'),
#        ('Pears', 'Babyfood, junior, pears, fruit'),
#        ('Pears', 'Babyfood, strained, pears, fruit'),
#        ('Pears', 'Babyfood, toddler, dices, pears'),
#        ('Pears', 'Broccoli, unprepared, spears, frozen'),
#        ('Pears', 'Pears, bartlett, raw'), ('Pears', 'Pears, bosc, raw'),
#        ('Pears', 'Pears, drained, heavy syrup, canned'),
#        ('Pears', 'Pears, green anjou, raw'), ('Pears', 'Pears, raw'),
#        ('Pears', 'Pears, raw, asian'), ('Pears', 'Pears, red anjou, raw'),
#        ('Pears', 'Pears, uncooked, sulfured, dried'),
#        ('Pears', 'Prickly pears, raw'),
#        ('Pineapple', 'Babyfood, junior, applesauce and pineapple, fruit'),
#        ('Pineapple', 'Babyfood, junior, bananas and pineapple with tapioca, fruit'),
#        ('Pineapple', 'Babyfood, junior, pears and pineapple, fruit'),
#        ('Pineapple', 'Babyfood, orange and pineapple, juice'),
#        ('Pineapple', 'Babyfood, strained, applesauce and pineapple, fruit'),
#        ('Pineapple', 'Babyfood, strained, bananas and pineapple with tapioca, fruit'),
#        ('Pineapple', 'Babyfood, strained, pears and pineapple, fruit'),
#        ('Pineapple', 'Babyfood, strained, pineapple, fruit pudding, dessert'),
#        ('Pineapple', 'Beverages, Orange Pineapple, V8 SPLASH Juice Drinks'),
#        ('Pineapple', 'Beverages, canned, pineapple and orange juice drink'),
#        ('Pineapple', 'Cake, prepared from recipe, pineapple upside-down'),
#        ('Pineapple', 'Frozen novelties, pineapple-coconut, ice type'),
#        ('Pineapple', 'Orange Pineapple Juice Blend'),
#        ('Pineapple', 'Pineapple juice, undiluted, unsweetened, frozen concentrate'),
#        ('Pineapple', 'Pineapple, all varieties, raw'),
#        ('Pineapple', 'Pineapple, drained, juice pack, canned'),
#        ('Pineapple', 'Pineapple, extra sweet variety, raw'),
#        ('Pineapple', 'Pineapple, solids and liquids, extra heavy syrup pack, canned'),
#        ('Pineapple', 'Pineapple, solids and liquids, heavy syrup pack, canned'),
#        ('Pineapple', 'Pineapple, solids and liquids, juice pack, canned'),
#        ('Pineapple', 'Pineapple, solids and liquids, light syrup pack, canned'),
#        ('Pineapple', 'Pineapple, solids and liquids, water pack, canned'),
#        ('Pineapple', 'Pineapple, sweetened, chunks, frozen'),
#        ('Pineapple', 'Pineapple, traditional varieties, raw'),
#        ('Pineapple', 'Toppings, pineapple'),
#        ('Plum', 'Babyfood, apple and plum, juice'),
#        ('Plum', 'Carissa, raw, (natal-plum)'),
#        ('Plum', 'Java-plum, raw, (jambolan)'), ('Plum', 'Plums, raw'),
#        ('Plum', 'Plums, uncooked, dried (prunes)'),
#        ('Plum', 'Sauce, ready-to-serve, plum'),
#        ('Pomegranate', 'Beverages, Cran Pomegranate, OCEAN SPRAY'),
#        ('Pomegranate', 'Beverages, zero calories, pomegranate with anti-oxidants, yumberry, bottled, water'),
#        ('Pomegranate', 'Pomegranate juice, bottled'),
#        ('Pomegranate', 'Pomegranates, raw'),
#        ('Potatoes', 'Babyfood, junior, sweet potatoes, vegetables'),
#        ('Potatoes', 'Babyfood, strained, corn and sweet potatoes'),
#        ('Potatoes', 'Babyfood, strained, sweet potatoes and chicken, dinner'),
#        ('Potatoes', 'Babyfood, sweet potatoes strained, vegetables'),
#        ('Potatoes', 'Babyfood, toddler, potatoes'),
#        ('Potatoes', 'Babyfood, toddler, potatoes with cheese and ham, dinner'),
#        ('Potatoes', 'Corned beef and potatoes in tortilla (Apache)'),
#        ('Potatoes', 'Fast foods, round pieces or patty, hash browns, potatoes'),
#        ('Potatoes', 'Potatoes, baked, flesh and skin, Russet'),
#        ('Potatoes', 'Potatoes, baked, flesh and skin, red'),
#        ('Potatoes', 'Potatoes, baked, flesh and skin, white'),
#        ('Potatoes', 'Potatoes, drained solids, canned'),
#        ('Potatoes', 'Potatoes, dry form, flakes without milk, dehydrated, mashed'),
#        ('Potatoes', 'Potatoes, dry form, granules with milk, dehydrated, mashed'),
#        ('Potatoes', 'Potatoes, dry form, granules without milk, dehydrated, mashed'),
#        ('Potatoes', 'Potatoes, home-prepared from recipe using butter, au gratin'),
#        ('Potatoes', 'Potatoes, home-prepared from recipe using margarine, au gratin'),
#        ('Potatoes', 'Potatoes, home-prepared with butter, scalloped'),
#        ('Potatoes', 'Potatoes, home-prepared with margarine, scalloped'),
#        ('Potatoes', 'Potatoes, home-prepared, hash brown'),
#        ('Potatoes', "Potatoes, home-prepared, o'brien"),
#        ('Potatoes', 'Potatoes, no salt added, drained solids, canned'),
#        ('Potatoes', "Potatoes, prepared, frozen, o'brien"),
#        ('Potatoes', 'Potatoes, prepared, with butter sauce, frozen, hash brown'),
#        ('Potatoes', 'Potatoes, raw, flesh and skin'),
#        ('Potatoes', 'Potatoes, raw, flesh and skin, red'),
#        ('Potatoes', 'Potatoes, raw, flesh and skin, russet'),
#        ('Potatoes', 'Potatoes, raw, flesh and skin, white'),
#        ('Potatoes', 'Potatoes, ready-to-eat, mashed'),
#        ('Potatoes', 'Potatoes, skin with salt, in skin, cooked, microwaved'),
#        ('Potatoes', 'Potatoes, skin, raw'),
#        ('Potatoes', 'Potatoes, solids and liquids, canned'),
#        ('Potatoes', 'Potatoes, unprepared, dry mix, au gratin'),
#        ('Potatoes', 'Potatoes, unprepared, dry mix, scalloped'),
#        ('Potatoes', 'Potatoes, unprepared, extruded, par fried, french fried, frozen'),
#        ('Potatoes', 'Potatoes, unprepared, frozen, cross cut, french fried'),
#        ('Potatoes', 'Potatoes, unprepared, frozen, french fried, yellow fleshed'),
#        ('Potatoes', "Potatoes, unprepared, frozen, o'brien"),
#        ('Potatoes', 'Potatoes, unprepared, frozen, salt added in processing, roasted'),
#        ('Potatoes', 'Potatoes, unprepared, frozen, wedge cut, french fried'),
#        ('Potatoes', 'Potatoes, unprepared, plain, frozen, hash brown'),
#        ('Potatoes', 'Potatoes, unprepared, refrigerated, hash brown'),
#        ('Potatoes', 'Potatoes, unprepared, whole, frozen'),
#        ('Potatoes', 'Potatoes, unprepared, with butter sauce, frozen, hash brown'),
#        ('Potatoes', 'Potatoes, whole milk added, home-prepared, mashed'),
#        ('Potatoes', 'Potatoes, whole milk and butter added, home-prepared, mashed'),
#        ('Potatoes', 'Potatoes, whole milk and margarine added, home-prepared, mashed'),
#        ('Potatoes', 'Potatoes, with salt, drained, boiled, cooked, whole, frozen'),
#        ('Potatoes', 'Potatoes, with salt, flesh and skin, baked'),
#        ('Potatoes', 'Potatoes, with salt, flesh, baked'),
#        ('Potatoes', 'Potatoes, with salt, flesh, cooked in skin, boiled'),
#        ('Potatoes', 'Potatoes, with salt, flesh, cooked in skin, microwaved'),
#        ('Potatoes', 'Potatoes, with salt, flesh, cooked without skin, boiled'),
#        ('Potatoes', 'Potatoes, with salt, skin only, baked'),
#        ('Potatoes', 'Potatoes, with salt, skin, cooked in skin, boiled'),
#        ('Potatoes', 'Potatoes, without salt, drained, boiled, cooked, whole, frozen'),
#        ('Potatoes', 'Potatoes, without salt, flesh and skin, baked'),
#        ('Potatoes', 'Potatoes, without salt, flesh, baked'),
#        ('Potatoes', 'Potatoes, without salt, flesh, cooked in skin, boiled'),
#        ('Potatoes', 'Potatoes, without salt, flesh, cooked in skin, microwaved'),
#        ('Potatoes', 'Potatoes, without salt, flesh, cooked without skin, boiled'),
#        ('Potatoes', 'Potatoes, without salt, skin, baked'),
#        ('Potatoes', 'Potatoes, without salt, skin, cooked in skin, boiled'),
#        ('Potatoes', 'Potatoes, without salt, skin, cooked in skin, microwaved'),
#        ('Potatoes', 'Snack, plain, made from dried potatoes, potato chips'),
#        ('Potatoes', 'Snacks, cheese-flavor, made from dried potatoes, potato chips'),
#        ('Potatoes', 'Snacks, reduced fat, made from dried potatoes, potato chips'),
#        ('Potatoes', 'Sweet Potatoes, unprepared, frozen, crosscut, french fried'),
#        ('Pumpkin', 'Fish, dry heat, cooked, pumpkin seed, sunfish'),
#        ('Pumpkin', 'Fish, raw, pumpkin seed, sunfish'),
#        ('Pumpkin', "KELLOGG'S, Pumpkin Spice, Waffles, EGGO Seasons"),
#        ('Pumpkin', 'Pie, commercially prepared, pumpkin'),
#        ('Pumpkin', 'Pie, prepared from recipe, pumpkin'),
#        ('Pumpkin', 'Pumpkin flowers, raw'),
#        ('Pumpkin', 'Pumpkin flowers, without salt, drained, boiled, cooked'),
#        ('Pumpkin', 'Pumpkin leaves, raw'),
#        ('Pumpkin', 'Pumpkin leaves, with salt, drained, boiled, cooked'),
#        ('Pumpkin', 'Pumpkin leaves, without salt, drained, boiled, cooked'),
#        ('Pumpkin', 'Pumpkin pie mix, canned'),
#        ('Pumpkin', 'Pumpkin, raw'),
#        ('Pumpkin', 'Pumpkin, with salt, canned'),
#        ('Pumpkin', 'Pumpkin, with salt, drained, boiled, cooked'),
#        ('Pumpkin', 'Pumpkin, with salt, drained, boiled, cooked, flowers'),
#        ('Pumpkin', 'Pumpkin, without salt, canned'),
#        ('Pumpkin', 'Pumpkin, without salt, drained, boiled, cooked'),
#        ('Pumpkin', 'Seeds, dried, pumpkin and squash seed kernels'),
#        ('Pumpkin', 'Spices, pumpkin pie spice'),
#        ('Radish', 'Horseradish, prepared'),
#        ('Radish', 'Radish seeds, raw, sprouted'),
#        ('Radish', 'Radishes, dried, oriental'),
#        ('Radish', 'Radishes, pickled, hawaiian style'),
#        ('Radish', 'Radishes, raw'), ('Radish', 'Radishes, raw, oriental'),
#        ('Radish', 'Radishes, raw, white icicle'),
#        ('Radish', 'Sauce, horseradish'),
#        ('Raspberries', 'Raspberries, raw'),
#        ('Raspberries', 'Raspberries, solids and liquids, heavy syrup pack, red, canned'),
#        ('Raspberries', 'Raspberries, sweetened, red, frozen'),
#        ('Raspberries', 'Raspberries, unsweetened, frozen'),
#        ('Raspberries', 'Raspberries, wild (Northern Plains Indians)'),
#        ('Spinach', 'Babyfood, strained, creamed, spinach, vegetables'),
#        ('Spinach', 'Malabar spinach, cooked'),
#        ('Spinach', 'Mustard spinach, raw, (tendergreen)'),
#        ('Spinach', 'New Zealand spinach, raw'),
#        ('Spinach', 'New zealand spinach, with salt, drained, boiled, cooked'),
#        ('Spinach', 'Noodles, cooked, enriched, spinach, egg'),
#        ('Spinach', 'Noodles, dry, enriched, spinach, egg'),
#        ('Spinach', 'Pasta, as purchased, spinach, fresh-refrigerated'),
#        ('Spinach', 'Pasta, cooked, spinach, fresh-refrigerated'),
#        ('Spinach', 'Spaghetti, cooked, spinach'),
#        ('Spinach', 'Spaghetti, dry, spinach'),
#        ('Spinach', 'Spinach souffle'),
#        ('Spinach', 'Spinach, drained solids, regular pack, canned'),
#        ('Spinach', 'Spinach, raw'),
#        ('Spinach', 'Spinach, solids and liquids, no salt added, canned'),
#        ('Spinach', 'Spinach, solids and liquids, regular pack, canned'),
#        ('Spinach', 'Spinach, unprepared, chopped or leaf, frozen'),
#        ('Spinach', 'Spinach, with salt, drained, boiled, cooked'),
#        ('Spinach', 'Spinach, without salt, drained, boiled, cooked'),
#        ('Spinach', 'Vinespinach, raw, (basella)'),
#        ('Strawberries', 'Cereals ready-to-eat, with real strawberries, HONEY BUNCHES OF OATS, POST'),
#        ('Strawberries', 'Strawberries, raw'),
#        ('Strawberries', 'Strawberries, sliced, sweetened, frozen'),
#        ('Strawberries', 'Strawberries, solids and liquids, heavy syrup pack, canned'),
#        ('Strawberries', 'Strawberries, unsweetened, frozen'),
#        ('Strawberries', 'Strawberries, whole, sweetened, frozen'),
#        ('Sweet potatoes', 'Sweet Potatoes, salt added in processing, frozen as packaged, french fried'),
#        ('Tomatoes', 'Tomatoes, canned, crushed'),
#        ('Tomatoes', 'Tomatoes, cooked, ripe, red'),
#        ('Tomatoes', 'Tomatoes, drained, packed in oil, sun-dried'),
#        ('Tomatoes', 'Tomatoes, packed in tomato juice, canned, ripe, red'),
#        ('Tomatoes', 'Tomatoes, raw, green'),
#        ('Tomatoes', 'Tomatoes, raw, orange'),
#        ('Tomatoes', 'Tomatoes, raw, yellow'),
#        ('Tomatoes', 'Tomatoes, stewed, canned, ripe, red'),
#        ('Tomatoes', 'Tomatoes, stewed, cooked, ripe, red'),
#        ('Tomatoes', 'Tomatoes, sun-dried'),
#        ('Tomatoes', 'Tomatoes, with green chilies, canned, ripe, red'),
#        ('Tomatoes', 'Tomatoes, with salt, cooked, ripe, red'),
#        ('Tomatoes', 'Tomatoes, year round average, raw, ripe, red'),
#        ('Turnip greens', 'Turnip greens and turnips, unprepared, frozen'),
#        ('Turnip greens', 'Turnip greens and turnips, with salt, drained, boiled, cooked, frozen'),
#        ('Turnip greens', 'Turnip greens and turnips, without salt, drained, boiled, cooked, frozen'),
#        ('Turnip greens', 'Turnip greens, no salt added, canned'),
#        ('Turnip greens', 'Turnip greens, raw'),
#        ('Turnip greens', 'Turnip greens, solids and liquids, canned'),
#        ('Turnip greens', 'Turnip greens, unprepared, frozen'),
#        ('Turnip greens', 'Turnip greens, with salt, drained, boiled, cooked'),
#        ('Turnip greens', 'Turnip greens, with salt, drained, boiled, cooked, frozen'),
#        ('Turnip greens', 'Turnip greens, without salt, drained, boiled, cooked'),
#        ('Turnip greens', 'Turnip greens, without salt, drained, boiled, cooked, frozen'),
#        ('Watermelon', 'Seeds, dried, watermelon seed kernels'),
#        ('Watermelon', 'Watermelon, raw'),
#        ('Zucchini', 'Squash, canned, italian style, zucchini, summer'),
#        ('Zucchini', 'Squash, raw, baby, zucchini'),
#        ('Zucchini', 'Squash, raw, includes skin, zucchini, summer'),
#        ('Zucchini', 'Squash, unprepared, frozen, includes skin, zucchini, summer')],
#       dtype=object)

# %%
matched_items = matched_df.groupby(['Item', 'name'])['score'].mean().index.get_level_values('Item').unique()
matched_items
# Out:
# Index(['Apples', 'Apricots', 'Artichoke', 'Asparagus', 'Avocados', 'Bananas',
#        'Beets', 'Black beans', 'Blackberries', 'Blueberries', 'Broccoli',
#        'Brussels sprouts', 'Butternut squash', 'Cabbage, red', 'Cantaloupe',
#        'Carrots', 'Carrots, baby', 'Carrots, raw whole', 'Cauliflower',
#        'Cherries', 'Clementines', 'Collard greens', 'Corn', 'Cranberries',
#        'Dates', 'Figs', 'Grapefruit', 'Grapes', 'Green beans', 'Green peppers',
#        'Honeydew', 'Kale', 'Kidney beans', 'Kiwi', 'Lentils', 'Lima beans',
#        'Mustard greens', 'Nectarines', 'Okra', 'Olives', 'Onions', 'Oranges',
#        'Papaya', 'Peaches', 'Pears', 'Pineapple', 'Plum', 'Pomegranate',
#        'Potatoes', 'Pumpkin', 'Radish', 'Raspberries', 'Spinach',
#        'Strawberries', 'Sweet potatoes', 'Tomatoes', 'Turnip greens',
#        'Watermelon', 'Zucchini'],
#       dtype='object', name='Item')

# %%
matched_items.nunique()
# Out:
# 59

# %%
prices.Item.nunique()
# Out:
# 107

# %%
# which price items didn't find a match

prices.Item[prices.Item.isin(matched_items)==False]
# Out:
# 1                                    Apples, applesauce
# 5                             Apricots, packed in juice
# 6                    Apricots, packed in syrup or water
# 9                                        Berries, mixed
# 16                   Cherries, packed in syrup or water
# 21                      Fruit cocktail, packed in juice
# 22             Fruit cocktail, packed in syrup or water
# 26                                     Grapes (raisins)
# 31                                              Mangoes
# 32                                              Mangoes
# 40                             Peaches, packed in juice
# 41                    Peaches, packed in syrup or water
# 44                               Pears, packed in juice
# 45                      Pears, packed in syrup or water
# 47                           Pineapple, packed in juice
# 48                  Pineapple, packed in syrup or water
# 53                                        Plum (prunes)
# 62                                         Acorn squash
# 72                                        Blackeye peas
# 73                                        Blackeye peas
# 74                                     Broccoli florets
# 75                                       Broccoli heads
# 80                                       Cabbage, green
# 82                                  Cabbage, sauerkraut
# 83                                Carrots, cooked whole
# 88                                  Cauliflower florets
# 89                                    Cauliflower heads
# 91                              Celery, trimmed bunches
# 92                                        Celery sticks
# 99                                  Cucumbers with peel
# 100                              Cucumbers without peel
# 101                                Great northern beans
# 102                                Great northern beans
# 106                                          Green peas
# 107                                          Green peas
# 114                                    Lettuce, iceberg
# 115                             Lettuce, romaine, heads
# 116                            Lettuce, romaine, hearts
# 120                    Mixed vegetables, peas & carrots
# 121                    Mixed vegetables, peas & carrots
# 122           Mixed vegetables, peas, corn, green beans
# 123    Mixed vegetables, broccoli, cauliflower, carrots
# 124                                    Mushrooms, whole
# 125                                   Mushrooms, sliced
# 128                                          Navy beans
# 129                                          Navy beans
# 134                                         Pinto beans
# 135                                         Pinto beans
# 137                              Potatoes, french fries
# 141                                         Red peppers
# 142                                     Spinach, boiled
# 143                                  Spinach, eaten raw
# 147                            Tomatoes, grape & cherry
# 148                               Tomatoes, roma & plum
# 149                               Tomatoes, large round
# Name: Item, dtype: object

# %%
# manually verify each match

matched_df.groupby(['Item', 'name'])['score'].mean().loc[(matched_items[57],)].index

# 0 , Apples,           "Apples, with skin ..."
# 1 , Apricots,         "Apricots, raw"
# 2 , Artichokes,       'Artichokes, raw, (globe or french)'
# 3 , Asparagus,        'Asparagus, raw'
# 4 , Avocados,         {all matches}
# 5 , Bananas,          'Bananas, raw'
# 6 , Beets,            'Beets, raw'
# 7 , Black beans,      {no matches}
# 8 , Blackberries,     ['Blackberries, raw','Blackberries, raw (Alaska Native), wild','Blackberries, unsweetened, frozen']
# 9 , Blueberries,      ['Blueberries, frozen (Alaska Native), wild','Blueberries, frozen, wild', 'Blueberries, raw', 'Blueberries, raw (Alaska Native), wild', 'Blueberries, unsweetened, frozen']
# 10 , Broccoli,         ['Broccoli raab, raw', 'Broccoli, raw', 'Broccoli, raw, flower clusters']
# 11 , Brussels sprouts, 'Brussels sprouts, raw', 'Brussels sprouts, unprepared, frozen'
# 12 , Butternut squash  {no matches}
# 13 , Cabbage, red      'Cabbage, raw, red'
# 14 , 'Cantaloupe'      'Melons, raw, cantaloupe'
# 15 , 'Carrots'         {! more Items to check instead of just 'Carrots'}
# 16 , 'Carrots, baby',  ['Carrots, raw, baby']
# 17 , 'Carrots, raw whole' ['Carrots, raw']
# 18 , 'Cauliflower',    {there's other records for Fresh} ['Cauliflower, raw', 'Cauliflower, unprepared, frozen']
# 19 , 'Cherries'        ['Cherries, drained, heavy syrup, pitted, canned, sweet', 'Cherries, drained, water pack, canned, sour','Cherries, raw, red, sour', 'Cherries, raw, sweet']
# 20 , Clementines,      ['Clementines, raw']
# 21 , Collard greens,   {no matches} ['Collards, raw', 'Collards, unprepared, chopped, frozen', 'Collards, without salt, drained, boiled, cooked, chopped, frozen']
# 22 , Corn,             ['Corn, raw, white, sweet', 'Corn, raw, yellow, sweet','Corn, drained solids, whole kernel, canned, yellow, sweet','Corn, drained solids, whole kernel, canned, white, sweet','Corn, unprepared, kernels cut off cob, frozen, yellow, sweet','Corn, unprepared, kernels cut off cob, frozen, white, sweet']
# 23 , Cranberries       Cranberries, sweetened, dried
# 24 , Dates             ['Dates, deglet noor', 'Dates, medjool']
# 25 , Figs              ['Figs, stewed, dried', 'Figs, uncooked, dried']
# 26 , Grapefruit        ['Grapefruit, California, white, raw','Grapefruit, all areas, white, raw','Grapefruit, Florida, white, raw','Grapefruit, Florida, pink and red, raw','Grapefruit, all areas, pink and red, raw','Grapefruit, all areas, pink and red and white, raw','Grapefruit, California and Arizona, pink and red, raw']
# 27 , Grapes            'Grapes, raw, american type (slip skin)'
# 28 , Green beans       'Beans, raw, green, snap', Beans, unprepared, all styles, frozen, green, snap', Beans, drained solids, no salt added, canned, green, snap]
# 29 , Green peppers     'Peppers, raw, green, sweet'
# 30 , Honeydew          ['Honey', 'Melons, raw, honeydew']
# 31 , Kale              ['Kale, raw', 'Kale, raw, scotch', 'Kale, unprepared, frozen']
# 32 , Kidney beans      ['Beans, raw, mature seeds, red, kidney', 'Beans, raw, mature seeds, royal red, kidney','Beans, raw, mature seeds, all types, kidney', 'Beans, canned, mature seeds, all types, kidney']
# 33 , Kiwi              ['Kiwifruit, raw, ZESPRI SunGold', 'Kiwifruit, raw, green']
# 34 , Lentiles          ['Lentils, raw', 'Lentils, raw, pink or red']
# 35 , Lima beans        ['Lima beans, raw, immature seeds','Lima beans, raw, mature seeds, large','Lima beans, canned, mature seeds, large', 'Lima beans, unprepared, baby, frozen, immature seeds']
# 36 , 'Mustard greens'  ['Mustard greens, unprepared, frozen', ] {no match for canned}
# 37 , Nectarines        'Nectarines, raw'
# 38 , Okra              ['Okra, raw', 'Okra, unprepared, frozen']
# 39 , Olives            ['Olives, canned (jumbo-super colossal), ripe','Olives, canned (small-extra large), ripe','Olives, green, canned or bottled, pickled']
# 40 , Onions            ['Onions, raw, sweet','Onions, raw, welsh','Onions, raw']
# 41 , Oranges           ['Oranges, Florida, raw','Oranges, navels, raw','Oranges, with peel, raw','Oranges, valencias, California, raw','Oranges, all commercial varieties, raw']
# 42 , Papaya            'Papayas, raw' {fresh only}
# 43 , Peaches           ['Peaches, raw, yellow','Peaches, sweetened, sliced, frozen','Peaches, drained, heavy syrup, canned','Peaches, solids and liquids, water pack, canned','Peaches, solids and liquids, juice pack, canned','Peaches, solids and liquids, heavy syrup pack, canned','Peaches, solids and liquids, light syrup pack, canned','Peaches, solids and liquids, extra light syrup, canned']
# 44 , Pears             ['Pears, red anjou, raw','Pears, bartlett, raw','Pears, raw, asian','Pears, bosc, raw','Pears, raw','Pears, green anjou, raw','Pears, drained, heavy syrup, canned','Pears, solids and liquids, water pack, canned','Pears, solids and liquids, juice pack, canned','Pears, solids and liquids, light syrup pack, canned','Pears, solids and liquids, heavy syrup pack, canned','Pears, solids and liquids, extra light syrup pack, canned','Pears, solids and liquids, extra heavy syrup pack, canned']
# 45 , Pineapple         ['Pineapple, all varieties, raw','Pineapple, drained, juice pack, canned','Pineapple, solids and liquids, juice pack, canned','Pineapple, solids and liquids, water pack, canned','Pineapple, solids and liquids, heavy syrup pack, canned','Pineapple, solids and liquids, light syrup pack, canned','Pineapple, solids and liquids, extra heavy syrup pack, canned']
# 46 , Plum              ['Plums, raw','Plums, uncooked, dried (prunes)']
# 47 , Pomegranate       'Pomegranates, raw'
# 48 , Potatoes          ['Potatoes, skin, raw','Potatoes, raw, flesh and skin, red','Potatoes, raw, flesh and skin','Potatoes, raw, flesh and skin, russet','Potatoes, raw, flesh and skin, white',['Potatoes, unprepared, extruded, par fried, french fried, frozen','Potatoes, without salt, heated in oven, prepared, extruded, par fried, french fried, frozen','Potatoes, with salt, heated in oven, prepared, cottage-cut, par fried, french fried, frozen', 'Potatoes, drained solids, canned','Potatoes, solids and liquids, canned','Potatoes, no salt added, drained solids, canned']
# 49 , Pumpkin           ['Pumpkin, without salt, canned', 'Pumpkin, with salt, canned']
# 50 , Radish            ['Radishes, raw',  'Radishes, raw, white icicle', 'Radishes, raw, oriental']
# 51 , Raspberries       ['Raspberries, raw','Raspberries, unsweetened, frozen','Raspberries, sweetened, red, frozen']
# 52 , Spinach           ['Spinach, raw','Spinach, unprepared, chopped or leaf, frozen','Spinach, without salt, drained, boiled, cooked, chopped or leaf, frozen','Spinach, with salt, drained, boiled, cooked, chopped or leaf, frozen']
# 53 , Strawberries      ['Strawberries, raw','Strawberries, unsweetened, frozen','Strawberries, sliced, sweetened, frozen','Strawberries, whole, sweetened, frozen']
# 54 , Sweet potatoes    ['Sweet potato, unprepared, raw']
# 55 , Tomatoes          ['Tomatoes, canned, crushed','Tomatoes, stewed, canned, ripe, red'] ... there are unmatched FRESH tomatoes
# 56 , Turnip greens     ['Turnip greens, raw', 'Turnip greens, no salt added, canned','Turnip greens, solids and liquids, canned','Turnip greens, unprepared, frozen','Turnip greens, with salt, drained, boiled, cooked, frozen','Turnip greens, without salt, drained, boiled, cooked, frozen']
# 57 , Watermelon        ['Watermelon, raw']
# 58 , Zucchini          ['Squash, raw, baby, zucchini', 'Squash, raw, includes skin, zucchini, summer']
# Out:
# Index(['Seeds, dried, watermelon seed kernels', 'Watermelon, raw'], dtype='object', name='name')

# %%
prices[prices['Item'].str.contains('Zucchini')]
# Out:
#          Item   Form  RetailPrice  PricePer100Grams
# 154  Zucchini  Fresh       1.5489          0.341474

# %%
food[food['name'].str.contains('raw.*ucchini', regex=True)]['name'].drop_duplicates().to_list()
# Out:
# ['Squash, raw, baby, zucchini', 'Squash, raw, includes skin, zucchini, summer']

# %%
food.head()
# Out:
#               name food_types storage_state grade Salt      variable  amount  \
# 0       Cornstarch                                      serving_size   100.0
# 1     Nuts, pecans                                      serving_size   100.0
# 2    Eggplant, raw                                      serving_size   100.0
# 3   Teff, uncooked                                      serving_size   100.0
# 4  Sherbet, orange                                      serving_size   100.0
#
#   unit of measure
# 0               g
# 1               g
# 2               g
# 3               g
# 4               g

# %%
all = food.merge(matched_df, on='name').merge(prices, on='Item')
all = all[['name', 'Item', 'food_types', 'storage_state','grade', 'Salt', 'variable', 'amount', 'unit of measure', 'Form', 'RetailPrice', 'PricePer100Grams']]
all.head()
# Out:
#          name  Item food_types storage_state grade Salt      variable  amount  \
# 0  Cornstarch  Corn                                      serving_size   100.0
# 1  Cornstarch  Corn                                      serving_size   100.0
# 2  Cornstarch  Corn                                      serving_size   100.0
# 3  Cornstarch  Corn                                          calories   381.0
# 4  Cornstarch  Corn                                          calories   381.0
#
#   unit of measure    Form  RetailPrice  PricePer100Grams
# 0               g   Fresh       1.8908          0.416850
# 1               g  Canned       1.0287          0.226790
# 2               g  Frozen       1.6642          0.366893
# 3             NaN   Fresh       1.8908          0.416850
# 4             NaN  Canned       1.0287          0.226790

# %% [markdown]
# # Cost per Nutrient

# %%
all['dollarsPerNutrient'] = all['PricePer100Grams']/all['amount']
all.head()
# Out:
#          name  Item food_types storage_state grade Salt      variable  amount  \
# 0  Cornstarch  Corn                                      serving_size   100.0
# 1  Cornstarch  Corn                                      serving_size   100.0
# 2  Cornstarch  Corn                                      serving_size   100.0
# 3  Cornstarch  Corn                                          calories   381.0
# 4  Cornstarch  Corn                                          calories   381.0
#
#   unit of measure    Form  RetailPrice  PricePer100Grams  dollarsPerNutrient
# 0               g   Fresh       1.8908          0.416850            0.004169
# 1               g  Canned       1.0287          0.226790            0.002268
# 2               g  Frozen       1.6642          0.366893            0.003669
# 3             NaN   Fresh       1.8908          0.416850            0.001094
# 4             NaN  Canned       1.0287          0.226790            0.000595

# %%
# all[((all.storage_state != all.Form) | (all.storage_state != '')) & (all.variable=='calories')].iloc[:50]

# %%
# need to solve for mismatching storage state...

all[['storage_state', 'Form']].drop_duplicates()
# Out:
#       storage_state    Form
# 0                     Fresh
# 1                    Canned
# 2                    Frozen
# 6075         Frozen   Fresh
# 6076         Frozen  Canned
# 6077         Frozen  Frozen
# 9000          Dried   Fresh
# 9001          Dried  Canned
# 9002          Dried  Frozen
# 11250        Canned  Frozen
# 12000                 Dried
# 13800        Canned  Canned
# 15525        Canned   Fresh
# 17101        Canned   Dried
# 34726        Frozen   Dried
# 50025         Fresh  Canned
# 50026         Fresh  Frozen

# %%
plt.figure(figsize=(8,5),dpi=150)

data=(all[
    (all['variable']=='calories') & 
    (all['name'].str.contains('raw')) & 
    (all['Form']=='Fresh')
    ]
)

sns.scatterplot(data=data
                ,x='amount'
                ,y='dollarsPerNutrient'
               )
x = data.amount
y = data.dollarsPerNutrient
labels = data.name

# Add labels to the markers
for i, label in enumerate(labels):
    if x.iloc[i] > 200:
        pass
    else:
        plt.text(x.iloc[i], y.iloc[i], label[:30]+'...', ha='left', va='bottom', fontsize=6, alpha=0.5)
plt.xlim((0,200));

# %% [markdown]
# # Daily Value Requirements

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage
url = "https://www.fda.gov/food/nutrition-facts-label/daily-value-nutrition-and-supplement-facts-labels"

# Send a GET request to the webpage
response = requests.get(url)

# Parse the HTML content of the webpage using BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find the table by its class name
table = soup.find("table", {"class": "table table-bordered"})

# Extract table data and convert it to a DataFrame
table_data = []
for row in table.find_all("tr"):
    row_data = [cell.get_text(strip=True) for cell in row.find_all(["th", "td"])]
    table_data.append(row_data)

dv = pd.DataFrame(table_data[1:], columns=table_data[0])
dv
# Out:
#               Nutrient    Current Daily Value
# 0         Added sugars                    50g
# 1               Biotin                  30mcg
# 2              Calcium                 1300mg
# 3             Chloride                 2300mg
# 4              Choline                  550mg
# 5          Cholesterol                  300mg
# 6             Chromium                  35mcg
# 7               Copper                  0.9mg
# 8        Dietary Fiber                    28g
# 9                  Fat                    78g
# 10   Folate/Folic Acid             400mcg DFE
# 11              Iodine                 150mcg
# 12                Iron                   18mg
# 13           Magnesium                  420mg
# 14           Manganese                  2.3mg
# 15          Molybdenum                  45mcg
# 16              Niacin                16mg NE
# 17    Pantothenic Acid                    5mg
# 18          Phosphorus                 1250mg
# 19           Potassium                 4700mg
# 20             Protein                    50g
# 21          Riboflavin                  1.3mg
# 22       Saturated fat                    20g
# 23            Selenium                  55mcg
# 24              Sodium                 2300mg
# 25             Thiamin                  1.2mg
# 26  Total carbohydrate                   275g
# 27           Vitamin A             900mcg RAE
# 28          Vitamin B6                  1.7mg
# 29         Vitamin B12                 2.4mcg
# 30           Vitamin C                   90mg
# 31           Vitamin D                  20mcg
# 32           Vitamin E  15mg alpha-tocopherol
# 33           Vitamin K                 120mcg
# 34                Zinc                   11mg

# %%
# add calories

dv.loc[dv.index.size] = ['calories', '2000Kcal']
dv
# Out:
#               Nutrient    Current Daily Value
# 0         Added sugars                    50g
# 1               Biotin                  30mcg
# 2              Calcium                 1300mg
# 3             Chloride                 2300mg
# 4              Choline                  550mg
# 5          Cholesterol                  300mg
# 6             Chromium                  35mcg
# 7               Copper                  0.9mg
# 8        Dietary Fiber                    28g
# 9                  Fat                    78g
# 10   Folate/Folic Acid             400mcg DFE
# 11              Iodine                 150mcg
# 12                Iron                   18mg
# 13           Magnesium                  420mg
# 14           Manganese                  2.3mg
# 15          Molybdenum                  45mcg
# 16              Niacin                16mg NE
# 17    Pantothenic Acid                    5mg
# 18          Phosphorus                 1250mg
# 19           Potassium                 4700mg
# 20             Protein                    50g
# 21          Riboflavin                  1.3mg
# 22       Saturated fat                    20g
# 23            Selenium                  55mcg
# 24              Sodium                 2300mg
# 25             Thiamin                  1.2mg
# 26  Total carbohydrate                   275g
# 27           Vitamin A             900mcg RAE
# 28          Vitamin B6                  1.7mg
# 29         Vitamin B12                 2.4mcg
# 30           Vitamin C                   90mg
# 31           Vitamin D                  20mcg
# 32           Vitamin E  15mg alpha-tocopherol
# 33           Vitamin K                 120mcg
# 34                Zinc                   11mg
# 35            calories               2000Kcal

# %%
# split Daily Value from string into numeric amount and unit of measure

pattern = r'(\d+(?:\.\d+)?)\s?(\D+)?'
dv[['DV_amount','DV_UOM']] = dv['Current Daily Value'].str.extract(pattern)
dv['DV_amount'] = pd.to_numeric(dv['DV_amount'],errors='coerce')
dv = dv.drop(labels=['Current Daily Value'], axis=1)
dv['Nutrient'] = dv['Nutrient'].str.lower()
dv
# Out:
#               Nutrient  DV_amount               DV_UOM
# 0         added sugars       50.0                    g
# 1               biotin       30.0                  mcg
# 2              calcium     1300.0                   mg
# 3             chloride     2300.0                   mg
# 4              choline      550.0                   mg
# 5          cholesterol      300.0                   mg
# 6             chromium       35.0                  mcg
# 7               copper        0.9                   mg
# 8        dietary fiber       28.0                    g
# 9                  fat       78.0                    g
# 10   folate/folic acid      400.0              mcg DFE
# 11              iodine      150.0                  mcg
# 12                iron       18.0                   mg
# 13           magnesium      420.0                   mg
# 14           manganese        2.3                   mg
# 15          molybdenum       45.0                  mcg
# 16              niacin       16.0                mg NE
# 17    pantothenic acid        5.0                   mg
# 18          phosphorus     1250.0                   mg
# 19           potassium     4700.0                   mg
# 20             protein       50.0                    g
# 21          riboflavin        1.3                   mg
# 22       saturated fat       20.0                    g
# 23            selenium       55.0                  mcg
# 24              sodium     2300.0                   mg
# 25             thiamin        1.2                   mg
# 26  total carbohydrate      275.0                    g
# 27           vitamin a      900.0              mcg RAE
# 28          vitamin b6        1.7                   mg
# 29         vitamin b12        2.4                  mcg
# 30           vitamin c       90.0                   mg
# 31           vitamin d       20.0                  mcg
# 32           vitamin e       15.0  mg alpha-tocopherol
# 33           vitamin k      120.0                  mcg
# 34                zinc       11.0                   mg
# 35            calories     2000.0                 Kcal

# %%
all['variable'].unique()
# Out:
# array(['serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid',
#        'niacin', 'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene',
#        'vitamin_b12', 'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e',
#        'tocopherol_alpha', 'vitamin_k', 'calcium', 'copper', 'irom',
#        'magnesium', 'manganese', 'phosphorous', 'potassium', 'selenium',
#        'zink', 'protein', 'alanine', 'arginine', 'aspartic_acid',
#        'cystine', 'glutamic_acid', 'glycine', 'histidine',
#        'hydroxyproline', 'isoleucine', 'leucine', 'lysine', 'methionine',
#        'phenylalanine', 'proline', 'serine', 'threonine', 'tryptophan',
#        'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose',
#        'sucrose', 'fat', 'saturated_fatty_acids',
#        'monounsaturated_fatty_acids', 'polyunsaturated_fatty_acids',
#        'fatty_acids_total_trans', 'alcohol', 'ash', 'caffeine',
#        'theobromine', 'water'], dtype=object)

# %%
dv['Nutrient'].unique()
# Out:
# array(['added sugars', 'biotin', 'calcium', 'chloride', 'choline',
#        'cholesterol', 'chromium', 'copper', 'dietary fiber', 'fat',
#        'folate/folic acid', 'iodine', 'iron', 'magnesium', 'manganese',
#        'molybdenum', 'niacin', 'pantothenic acid', 'phosphorus',
#        'potassium', 'protein', 'riboflavin', 'saturated fat', 'selenium',
#        'sodium', 'thiamin', 'total carbohydrate', 'vitamin a',
#        'vitamin b6', 'vitamin b12', 'vitamin c', 'vitamin d', 'vitamin e',
#        'vitamin k', 'zinc', 'calories'], dtype=object)

# %%
matches = fuzzymatch(all['variable'].drop_duplicates(), dv['Nutrient'].drop_duplicates(), 90)
matches
# Out:
# 0.0 seconds elapsed
#                        variable            Nutrient       score
# 0                      calories            calories  100.000000
# 1                     total_fat                 fat   90.000000
# 2                 saturated_fat       saturated fat  100.000000
# 3                   cholesterol         cholesterol  100.000000
# 4                        sodium              sodium  100.000000
# 5                       choline             choline  100.000000
# 6                        folate   folate/folic acid   90.000000
# 7                    folic_acid   folate/folic acid   90.000000
# 8                        niacin              niacin  100.000000
# 9              pantothenic_acid    pantothenic acid  100.000000
# 10                   riboflavin          riboflavin  100.000000
# 11                      thiamin             thiamin  100.000000
# 12                    vitamin_a           vitamin a  100.000000
# 13                vitamin_a_rae           vitamin a   95.000000
# 14                  vitamin_b12         vitamin b12  100.000000
# 15                   vitamin_b6          vitamin b6  100.000000
# 16                    vitamin_c           vitamin c  100.000000
# 17                    vitamin_d           vitamin d  100.000000
# 18                    vitamin_e           vitamin e  100.000000
# 19                    vitamin_k           vitamin k  100.000000
# 20                      calcium             calcium  100.000000
# 21                       copper              copper  100.000000
# 22                    magnesium           magnesium  100.000000
# 23                    manganese           manganese  100.000000
# 24                  phosphorous          phosphorus   95.238095
# 25                    potassium           potassium  100.000000
# 26                     selenium            selenium  100.000000
# 27                      protein             protein  100.000000
# 28                 carbohydrate  total carbohydrate   90.000000
# 29                        fiber       dietary fiber   90.000000
# 30                       sugars        added sugars   90.000000
# 31                          fat                 fat  100.000000
# 32        saturated_fatty_acids                 fat   90.000000
# 33  monounsaturated_fatty_acids       saturated fat   90.000000
# 34  polyunsaturated_fatty_acids       saturated fat   90.000000
# 35      fatty_acids_total_trans                 fat   90.000000

# %%
all = all.merge(matches.iloc[:,:2], on='variable').merge(dv, on="Nutrient")
all
# Out:
#                                                     name            Item  \
# 0                                             Cornstarch            Corn
# 1                                             Cornstarch            Corn
# 2                                             Cornstarch            Corn
# 3                                 Snacks, cakes, popcorn            Corn
# 4                                 Snacks, cakes, popcorn            Corn
# ...                                                  ...             ...
# 33223  Corn with red and green peppers, solids and li...   Green peppers
# 33224  Tomato products, and celery, green peppers, wi...   Green peppers
# 33225  Restaurant, Arroz con frijoles negros (rice an...     Black beans
# 33226  Restaurant, Arroz con frijoles negros (rice an...     Black beans
# 33227  Sweet Potatoes, salt added in processing, froz...  Sweet potatoes
#
#        variable  amount unit of measure    Form  RetailPrice  \
# 0      calories  381.00             NaN   Fresh       1.8908
# 1      calories  381.00             NaN  Canned       1.0287
# 2      calories  381.00             NaN  Frozen       1.6642
# 3      calories  384.00             NaN   Fresh       1.8908
# 4      calories  384.00             NaN  Canned       1.0287
# ...         ...     ...             ...     ...          ...
# 33223    sugars    0.00             NaN   Fresh       1.2772
# 33224    sugars    7.36               g   Fresh       1.2772
# 33225    sugars    0.86               g  Canned       1.0281
# 33226    sugars    0.86               g   Dried       1.3753
# 33227    sugars   12.90               g   Fresh       1.1198
#
#        PricePer100Grams  dollarsPerNutrient      Nutrient  DV_amount DV_UOM
# 0              0.416850            0.001094      calories     2000.0   Kcal
# 1              0.226790            0.000595      calories     2000.0   Kcal
# 2              0.366893            0.000963      calories     2000.0   Kcal
# 3              0.416850            0.001086      calories     2000.0   Kcal
# 4              0.226790            0.000591      calories     2000.0   Kcal
# ...                 ...                 ...           ...        ...    ...
# 33223          0.281574                 inf  added sugars       50.0      g
# 33224          0.281574            0.038257  added sugars       50.0      g
# 33225          0.226657            0.263555  added sugars       50.0      g
# 33226          0.303202            0.352560  added sugars       50.0      g
# 33227          0.246874            0.019137  added sugars       50.0      g
#
# [33228 rows x 12 columns]

# %%
all['PercentOfDV'] = all['amount']/all['DV_amount']
all['CostForEntireDV'] = all['DV_amount']/all['amount'] * all['RetailPrice']
all
# Out:
#                                                     name            Item  \
# 0                                             Cornstarch            Corn
# 1                                             Cornstarch            Corn
# 2                                             Cornstarch            Corn
# 3                                 Snacks, cakes, popcorn            Corn
# 4                                 Snacks, cakes, popcorn            Corn
# ...                                                  ...             ...
# 33223  Corn with red and green peppers, solids and li...   Green peppers
# 33224  Tomato products, and celery, green peppers, wi...   Green peppers
# 33225  Restaurant, Arroz con frijoles negros (rice an...     Black beans
# 33226  Restaurant, Arroz con frijoles negros (rice an...     Black beans
# 33227  Sweet Potatoes, salt added in processing, froz...  Sweet potatoes
#
#        variable  amount unit of measure    Form  RetailPrice  \
# 0      calories  381.00             NaN   Fresh       1.8908
# 1      calories  381.00             NaN  Canned       1.0287
# 2      calories  381.00             NaN  Frozen       1.6642
# 3      calories  384.00             NaN   Fresh       1.8908
# 4      calories  384.00             NaN  Canned       1.0287
# ...         ...     ...             ...     ...          ...
# 33223    sugars    0.00             NaN   Fresh       1.2772
# 33224    sugars    7.36               g   Fresh       1.2772
# 33225    sugars    0.86               g  Canned       1.0281
# 33226    sugars    0.86               g   Dried       1.3753
# 33227    sugars   12.90               g   Fresh       1.1198
#
#        PricePer100Grams  dollarsPerNutrient      Nutrient  DV_amount DV_UOM  \
# 0              0.416850            0.001094      calories     2000.0   Kcal
# 1              0.226790            0.000595      calories     2000.0   Kcal
# 2              0.366893            0.000963      calories     2000.0   Kcal
# 3              0.416850            0.001086      calories     2000.0   Kcal
# 4              0.226790            0.000591      calories     2000.0   Kcal
# ...                 ...                 ...           ...        ...    ...
# 33223          0.281574                 inf  added sugars       50.0      g
# 33224          0.281574            0.038257  added sugars       50.0      g
# 33225          0.226657            0.263555  added sugars       50.0      g
# 33226          0.303202            0.352560  added sugars       50.0      g
# 33227          0.246874            0.019137  added sugars       50.0      g
#
#        PercentOfDV  CostForEntireDV
# 0           0.1905         9.925459
# 1           0.1905         5.400000
# 2           0.1905         8.735958
# 3           0.1920         9.847917
# 4           0.1920         5.357812
# ...            ...              ...
# 33223       0.0000              inf
# 33224       0.1472         8.676630
# 33225       0.0172        59.773256
# 33226       0.0172        79.959302
# 33227       0.2580         4.340310
#
# [33228 rows x 14 columns]

# %%
all.sort_values(['variable','CostForEntireDV']).head()
# Out:
#                                                name      Item variable  \
# 23832    Babyfood, dry, with bananas, mixed, cereal   Bananas  calcium
# 23833     Babyfood, dry, with bananas, rice, cereal   Bananas  calcium
# 23830  Babyfood, dry, with bananas, oatmeal, cereal   Bananas  calcium
# 23702                Babyfood, dry, rice and apples    Apples  calcium
# 23408      Potatoes, unprepared, dry mix, au gratin  Potatoes  calcium
#
#        amount unit of measure   Form  RetailPrice  PricePer100Grams  \
# 23832   696.0              mg  Fresh       0.5249          0.115721
# 23833   691.0              mg  Fresh       0.5249          0.115721
# 23830   651.0              mg  Fresh       0.5249          0.115721
# 23702   850.0              mg  Fresh       1.5193          0.334948
# 23408   311.0              mg  Fresh       0.6682          0.147313
#
#        dollarsPerNutrient Nutrient  DV_amount DV_UOM  PercentOfDV  \
# 23832            0.000166  calcium     1300.0     mg     0.535385
# 23833            0.000167  calcium     1300.0     mg     0.531538
# 23830            0.000178  calcium     1300.0     mg     0.500769
# 23702            0.000394  calcium     1300.0     mg     0.653846
# 23408            0.000474  calcium     1300.0     mg     0.239231
#
#        CostForEntireDV
# 23832         0.980417
# 23833         0.987511
# 23830         1.048187
# 23702         2.323635
# 23408         2.793119

# %%
all['rank_CostForEntireDV'] = all.groupby(['variable', 'Form'])['CostForEntireDV'].rank()
all.sort_values(['variable', 'rank_CostForEntireDV'])[(all['variable']=='calories') & (all['Form']=='Fresh')]
# Out:
# /var/folders/l8/tbybt_pn2j3_tzq2f_xysh340000gp/T/ipykernel_5682/2402948871.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   all.sort_values(['variable', 'rank_CostForEntireDV'])[(all['variable']=='calories') & (all['Form']=='Fresh')]
#                                                   name           Item  \
# 642              Seeds, dried, watermelon seed kernels     Watermelon
# 435  Snacks, cheese-flavor, made from dried potatoe...       Potatoes
# 391  Snack, plain, made from dried potatoes, potato...       Potatoes
# 758          Babyfood, dry, with bananas, rice, cereal        Bananas
# 447  Snacks, reduced fat, made from dried potatoes,...       Potatoes
# ..                                                 ...            ...
# 711  Asparagus, without salt, drained, boiled, cook...      Asparagus
# 528          Turnip greens, solids and liquids, canned  Turnip greens
# 705  Asparagus, solids and liquids, no salt added, ...      Asparagus
# 708  Asparagus, solids and liquids, regular pack, c...      Asparagus
# 555  Beverages, zero calories, pomegranate with ant...    Pomegranate
#
#      variable  amount unit of measure   Form  RetailPrice  PricePer100Grams  \
# 642  calories   557.0             NaN  Fresh       0.3604          0.079455
# 435  calories   551.0             NaN  Fresh       0.6682          0.147313
# 391  calories   545.0             NaN  Fresh       0.6682          0.147313
# 758  calories   404.0             NaN  Fresh       0.5249          0.115721
# 447  calories   502.0             NaN  Fresh       0.6682          0.147313
# ..        ...     ...             ...    ...          ...               ...
# 711  calories    18.0             NaN  Fresh       2.7576          0.607947
# 528  calories    14.0             NaN  Fresh       2.4176          0.532990
# 705  calories    15.0             NaN  Fresh       2.7576          0.607947
# 708  calories    15.0             NaN  Fresh       2.7576          0.607947
# 555  calories     5.0             NaN  Fresh       2.2350          0.492733
#
#      dollarsPerNutrient  Nutrient  DV_amount DV_UOM  PercentOfDV  \
# 642            0.000143  calories     2000.0   Kcal       0.2785
# 435            0.000267  calories     2000.0   Kcal       0.2755
# 391            0.000270  calories     2000.0   Kcal       0.2725
# 758            0.000286  calories     2000.0   Kcal       0.2020
# 447            0.000293  calories     2000.0   Kcal       0.2510
# ..                  ...       ...        ...    ...          ...
# 711            0.033775  calories     2000.0   Kcal       0.0090
# 528            0.038071  calories     2000.0   Kcal       0.0070
# 705            0.040530  calories     2000.0   Kcal       0.0075
# 708            0.040530  calories     2000.0   Kcal       0.0075
# 555            0.098547  calories     2000.0   Kcal       0.0025
#
#      CostForEntireDV  rank_CostForEntireDV
# 642         1.294075                   1.0
# 435         2.425408                   2.0
# 391         2.452110                   3.0
# 758         2.598515                   4.0
# 447         2.662151                   5.0
# ..               ...                   ...
# 711       306.400000                 383.5
# 528       345.371429                 385.0
# 705       367.680000                 386.5
# 708       367.680000                 386.5
# 555       894.000000                 388.0
#
# [388 rows x 15 columns]

# %%
all[all['rank_CostForEntireDV']<=1 & (all['Form']=='Fresh')]
# Out:
#                                                     name                Item  \
# 642                Seeds, dried, watermelon seed kernels          Watermelon
# 1565               Seeds, dried, watermelon seed kernels          Watermelon
# 2488               Seeds, dried, watermelon seed kernels          Watermelon
# 3411               Seeds, dried, watermelon seed kernels          Watermelon
# 4177   Cake, prepared from recipe, pineapple upside-down           Pineapple
# 5257               Seeds, dried, watermelon seed kernels          Watermelon
# 5550                                Oil, corn and canola                Corn
# 7103               Seeds, dried, watermelon seed kernels          Watermelon
# 7869   Cake, prepared from recipe, pineapple upside-down           Pineapple
# 8640            Potatoes, unprepared, dry mix, au gratin            Potatoes
# 9667   Potatoes, dry form, granules without milk, deh...            Potatoes
# 10366                          Radishes, dried, oriental              Radish
# 11642  Cereals ready-to-eat, with real strawberries, ...        Strawberries
# 12757          Babyfood, dry, with bananas, rice, cereal             Bananas
# 13365  Potatoes, dry form, flakes without milk, dehyd...            Potatoes
# 14603          Babyfood, dry, with bananas, rice, cereal             Bananas
# 15526          Babyfood, dry, with bananas, rice, cereal             Bananas
# 16443                                       Carrots, raw  Carrots, raw whole
# 17366                                       Carrots, raw  Carrots, raw whole
# 18103  Cereals ready-to-eat, with real strawberries, ...        Strawberries
# 18965                          Onions, dehydrated flakes              Onions
# 19826  Potatoes, dry form, flakes without milk, dehyd...            Potatoes
# 20872  Cereals ready-to-eat, with real strawberries, ...        Strawberries
# 21620  Snack, plain, made from dried potatoes, potato...            Potatoes
# 22722                                          Kale, raw                Kale
# 23832         Babyfood, dry, with bananas, mixed, cereal             Bananas
# 24640              Seeds, dried, watermelon seed kernels          Watermelon
# 25563              Seeds, dried, watermelon seed kernels          Watermelon
# 26341  Pineapple juice, undiluted, unsweetened, froze...           Pineapple
# 27409              Seeds, dried, watermelon seed kernels          Watermelon
# 28444              Bananas, or banana powder, dehydrated             Bananas
# 29050  Potatoes, dry form, granules without milk, deh...            Potatoes
# 30178              Seeds, dried, watermelon seed kernels          Watermelon
# 31213              Bananas, or banana powder, dehydrated             Bananas
# 31424                                   Corn bran, crude                Corn
# 32524                                              Honey            Honeydew
#
#                           variable     amount unit of measure   Form  \
# 642                       calories    557.000             NaN  Fresh
# 1565                     total_fat     47.000               g  Fresh
# 2488                           fat     47.370               g  Fresh
# 3411         saturated_fatty_acids      9.779               g  Fresh
# 4177       fatty_acids_total_trans     22.000              mg  Fresh
# 5257                 saturated_fat      9.800               g  Fresh
# 5550   monounsaturated_fatty_acids     58.537               g  Fresh
# 7103   polyunsaturated_fatty_acids     28.094               g  Fresh
# 7869                   cholesterol     22.000              mg  Fresh
# 8640                        sodium   2095.000              mg  Fresh
# 9667                       choline     56.600              mg  Fresh
# 10366                       folate    295.000             mcg  Fresh
# 11642                   folic_acid    304.000             mcg  Fresh
# 12757                       niacin     23.320              mg  Fresh
# 13365             pantothenic_acid      2.079              mg  Fresh
# 14603                   riboflavin      3.800              mg  Fresh
# 15526                      thiamin      3.970              mg  Fresh
# 16443                    vitamin_a  16706.000              IU  Fresh
# 17366                vitamin_a_rae    835.000             mcg  Fresh
# 18103                  vitamin_b12      4.800             mcg  Fresh
# 18965                   vitamin_b6      1.600              mg  Fresh
# 19826                    vitamin_c     81.000              mg  Fresh
# 20872                    vitamin_d    129.000              IU  Fresh
# 21620                    vitamin_e     13.720              mg  Fresh
# 22722                    vitamin_k    704.800             mcg  Fresh
# 23832                      calcium    696.000              mg  Fresh
# 24640                       copper      0.686              mg  Fresh
# 25563                    magnesium    515.000              mg  Fresh
# 26341                    manganese      3.439              mg  Fresh
# 27409                  phosphorous    755.000              mg  Fresh
# 28444                    potassium   1491.000              mg  Fresh
# 29050                     selenium     27.100             mcg  Fresh
# 30178                      protein     28.330               g  Fresh
# 31213                 carbohydrate     88.280               g  Fresh
# 31424                        fiber     79.000               g  Fresh
# 32524                       sugars     82.120               g  Fresh
#
#        RetailPrice  PricePer100Grams  dollarsPerNutrient            Nutrient  \
# 642         0.3604          0.079455            0.000143            calories
# 1565        0.3604          0.079455            0.001691                 fat
# 2488        0.3604          0.079455            0.001677                 fat
# 3411        0.3604          0.079455            0.008125                 fat
# 4177        0.5685          0.125333            0.005697                 fat
# 5257        0.3604          0.079455            0.008108       saturated fat
# 5550        1.8908          0.416850            0.007121       saturated fat
# 7103        0.3604          0.079455            0.002828       saturated fat
# 7869        0.5685          0.125333            0.005697         cholesterol
# 8640        0.6682          0.147313            0.000070              sodium
# 9667        0.6682          0.147313            0.002603             choline
# 10366       1.5770          0.347669            0.001179   folate/folic acid
# 11642       2.5800          0.568793            0.001871   folate/folic acid
# 12757       0.5249          0.115721            0.004962              niacin
# 13365       0.6682          0.147313            0.070858    pantothenic acid
# 14603       0.5249          0.115721            0.030453          riboflavin
# 15526       0.5249          0.115721            0.029149             thiamin
# 16443       0.8703          0.191868            0.000011           vitamin a
# 17366       0.8703          0.191868            0.000230           vitamin a
# 18103       2.5800          0.568793            0.118498         vitamin b12
# 18965       0.9751          0.214973            0.134358          vitamin b6
# 19826       0.6682          0.147313            0.001819           vitamin c
# 20872       2.5800          0.568793            0.004409           vitamin d
# 21620       0.6682          0.147313            0.010737           vitamin e
# 22722       2.5018          0.551552            0.000783           vitamin k
# 23832       0.5249          0.115721            0.000166             calcium
# 24640       0.3604          0.079455            0.115823              copper
# 25563       0.3604          0.079455            0.000154           magnesium
# 26341       0.5685          0.125333            0.036445           manganese
# 27409       0.3604          0.079455            0.000105          phosphorus
# 28444       0.5249          0.115721            0.000078           potassium
# 29050       0.6682          0.147313            0.005436            selenium
# 30178       0.3604          0.079455            0.002805             protein
# 31213       0.5249          0.115721            0.001311  total carbohydrate
# 31424       1.8908          0.416850            0.005277       dietary fiber
# 32524       0.9056          0.199651            0.002431        added sugars
#
#        DV_amount               DV_UOM  PercentOfDV  CostForEntireDV  \
# 642       2000.0                 Kcal     0.278500         1.294075
# 1565        78.0                    g     0.602564         0.598111
# 2488        78.0                    g     0.607308         0.593439
# 3411        78.0                    g     0.125372         2.874650
# 4177        78.0                    g     0.282051         2.015591
# 5257        20.0                    g     0.490000         0.735510
# 5550        20.0                    g     2.926850         0.646019
# 7103        20.0                    g     1.404700         0.256567
# 7869       300.0                   mg     0.073333         7.752273
# 8640      2300.0                   mg     0.910870         0.733585
# 9667       550.0                   mg     0.102909         6.493110
# 10366      400.0              mcg DFE     0.737500         2.138305
# 11642      400.0              mcg DFE     0.760000         3.394737
# 12757       16.0                mg NE     1.457500         0.360137
# 13365        5.0                   mg     0.415800         1.607023
# 14603        1.3                   mg     2.923077         0.179571
# 15526        1.2                   mg     3.308333         0.158660
# 16443      900.0              mcg RAE    18.562222         0.046886
# 17366      900.0              mcg RAE     0.927778         0.938048
# 18103        2.4                  mcg     2.000000         1.290000
# 18965        1.7                   mg     0.941176         1.036044
# 19826       90.0                   mg     0.900000         0.742444
# 20872       20.0                  mcg     6.450000         0.400000
# 21620       15.0  mg alpha-tocopherol     0.914667         0.730539
# 22722      120.0                  mcg     5.873333         0.425959
# 23832     1300.0                   mg     0.535385         0.980417
# 24640        0.9                   mg     0.762222         0.472828
# 25563      420.0                   mg     1.226190         0.293918
# 26341        2.3                   mg     1.495217         0.380212
# 27409     1250.0                   mg     0.604000         0.596689
# 28444     4700.0                   mg     0.317234         1.654614
# 29050       55.0                  mcg     0.492727         1.356125
# 30178       50.0                    g     0.566600         0.636075
# 31213      275.0                    g     0.321018         1.635110
# 31424       28.0                    g     2.821429         0.670157
# 32524       50.0                    g     1.642400         0.551388
#
#        rank_CostForEntireDV
# 642                     1.0
# 1565                    1.0
# 2488                    1.0
# 3411                    1.0
# 4177                    1.0
# 5257                    1.0
# 5550                    1.0
# 7103                    1.0
# 7869                    1.0
# 8640                    1.0
# 9667                    1.0
# 10366                   1.0
# 11642                   1.0
# 12757                   1.0
# 13365                   1.0
# 14603                   1.0
# 15526                   1.0
# 16443                   1.0
# 17366                   1.0
# 18103                   1.0
# 18965                   1.0
# 19826                   1.0
# 20872                   1.0
# 21620                   1.0
# 22722                   1.0
# 23832                   1.0
# 24640                   1.0
# 25563                   1.0
# 26341                   1.0
# 27409                   1.0
# 28444                   1.0
# 29050                   1.0
# 30178                   1.0
# 31213                   1.0
# 31424                   1.0
# 32524                   1.0
